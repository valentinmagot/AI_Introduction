# %% [markdown]
# ## Recuit simulé pour le problème du voyageur de commerce

# %% [markdown]
# CSI4506 Intelligence Artificielle
# Automne 2020
# Caroline Barrière, Julian Templeton et Justin Charbonneau

# %% [markdown]
# Ce devoir vous permettra de mieux comprendre les algorithmes de recherche aléatoire vus en classe, en particulier l'algorithme de *recuit simulé*, qui est une méthode connue qui exemplifie bien la *modification aléatoire*.  Au départ, une solution gloutonne est proposée.  Cette solution est révisée petit à petit pour arriver à une meilleure solution.
#
# Le domaine d'application utilisé ici pour expérimenter avec le *recuit simulé* est le problème du voyageur de commerce (Traveling salesman problem).  C'est un problème classique, dans lequel le but est de visiter toutes les villes d'un graphe interconnecté de villes, et ce, en parcourant la plus petite distance possible.
#
# Ce notebook va dabord explorer la __méthode gloutonne__ puis la __méthode gloutonne aléatoire__ pour enfin aboutir au __recuit simulé__.

# %% [markdown]
# ***DEVOIR***:
# Parcourir le notebook, en exécutant chaque cellule, une à une.
# Pour chaque **(TO DO)**, effectuer les tâches demandées.
# Quand vous avez terminé, signez (voir cette étape ajoutée à la fin) et soumettez votre notebook.
#
# Ce notebook sera évalué sur 20 points.
# Chaque **(TO DO)** aura un pointage associé.
# ***

# %% [markdown]
# **1. Nous définissons d'abord un petit nombre de villes**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# La méthode *showNodes* ci-bas nous permet de visualiser la position des villes.
#
# Les packages **matplotlib** , **networkx** et **numpy** doivent d'abord être installés.
#
# Pour faire l'installation des packages, ouvrir une invite de commande, et tapez **pip install networkx** ainsi que **pip install numpy** (Si vous avez linux ou un Mac, vous pouvez utiliser **pip3** au lieu de **pip** selon la configuration de votre environnement). Matplotlib devrait déjà être installé mais si ce n'est pas le cas, utilisez la commande **pip install matplotlib** pour l'installer.
#
# Vous pouvez également profiter des commandes magiques et insérer une cellule de code et inscrire **%pip install networkx**.  Une fois les packages installés, vous devrez probablement redémarrer le *kernel*.  Ensuite, vous serez en mesure d'exécuter la cellule ci-bas.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Mesurons les distances entre les villes
# D'abord, nous définissons une méthode pour calculer la distance entre deux villes spécifiques.  Ensuite nous définissons une méthode pour trouver l'ensemble des distances entre plusieurs paires de noeuds (villes).

# %%
import math

def dist(node1, node2):
    """
    Returns the euclidian distance between two nodes
    """
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
def distDict(nodes):
    """Building a dictionary of all pairs or distances"""
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %% [markdown]
# Ajoutons aussi une méthode pour trouver la ville la plus proche d'une autre ville.  Cette méthode sera utile plus tard.

# %%
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    """
    Find the min distance from node1 to all other nodes.
    It receives the node1 label, the labels of other nodes to test, and the precalculated distances between all nodes
    """
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Solution gloutonne d'abord
# Avant de pouvoir utiliser le *recuit simulé*, il faut une première solution sous-optimale.  Nous utilisons un algorithme glouton pour générer cette solution. D'abord, le choix du noeud initiale sera aléatoire, puis par après l'algorithme choisira toujours le noeud le plus près.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# #### 4. Visualisation d'un chemin dans le graphe
# Nous modifions légèrement la méthode *showNodes* vue précédemment pour devenir *showPath* et montrer un chemin dans un graphe dirigé.

# %%
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    """
    Small method to show a path
    It receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E'] and a dictionary of all the nodes and their positions
    """
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 points**
# 1. Sélectionner un seed (numéro entier) à spécifier ci-bas pour rendre votre code reproductible.
# 2. Exécuter la cellule pour initialiser le générateur de nombres pseudo-aléatoires avec un numéro d'initialisation (**une fois seulement**)
# 3. Exécuter les test en-dessous de la déclaration du générateur de nombre plusieurs fois (manuellement exécuter la cellule) jusqu'à l'optention de deux solutions identiques. Enregistrer le nombre de fois que vous avez exécuter la cellule dans la section réponse ainsi que les deux chemins pour les deux solutions dans la section réponse.
# 4. Exécuter les test en-dessous de la déclaration du générateur de nombre plusieurs fois encore jusqu'à l'obtention de résultats différents pour les deux solutions. Enregistrer le nombre de fois que vous avez exécuter la cellule ainsi que les deux différents chemins pour les deux solutions dans la section réponse.

# %% [markdown]
# **(Présentez vos réponses dans ce Markdown)**
# Nb d'exécutions pour générer deux solutions identiques gs1 et gs2 :  **4**
#
# Chemins des 2 solutions identiques gs1 et gs2 : **['A', 'C', 'B', 'D', 'E']**
#
# Nb d'exécutions pour générer deux solutions différentes gs1 et gs2 : **2**
# Chemins des 2 solutions différentes gs1 et gs2 : **['E', 'A', 'C', 'B', 'D'] et ['C', 'A', 'B', 'D', 'E']**

# %% [markdown]
# Initialiser le générateur de nombres

# %%
# (TO DO) for reproducibility
random.seed(4) # Enter any integer in the parenthesis to set the seed

# %% [markdown]
# Un test pour visualiser 2 solutions gloutonnes. Regardez la sortie de texte du chemin pour voir si le graphique tracé contient des arêtes qui passent par un nœud.

# %%
# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['E', 'A', 'C', 'B', 'D']
# ['C', 'A', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 points**
# Compléter la méthode ci-bas pour trouver la longueur total d'un chemin.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]    
        y = path[i+1]
        total += distanceDict.get((x, y))
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 5.414
# 6.414

# %% [markdown]
# **(TO DO) Q3 - 4 points**
# Ajouter 2 nouvelles villes (positionner les villes où vous voulez dans le graphe prédéfini de -2 à 2).  Donc, refaire la séquence d'étapes ci-haut (1) définir un graphe, (2) visualiser les positions des villes (3) contruire le dictionnaire des distances (4) trouver deux solutions gloutonnes (5) montrer les chemins pour ces solutions.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (-1,0), 'G': (0,1)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
print(moreDistances)
# (4) Find two unique greedy solutions 
gs3 = greedy_solution(moreCities)
gs4 = greedy_solution(moreCities)
# (5) Show the two unique paths found above along with their total distances
print(gs3)
showPath(gs3, moreCities)
print(totalDist(gs3, distances))
print(gs4)
showPath(gs4, moreCities)
print(totalDist(gs4, distances))
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('A', 'F'): 1.0, ('A', 'G'): 1.0, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('B', 'F'): 2.236, ('B', 'G'): 1.0, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('C', 'F'): 2.0, ('C', 'G'): 1.414, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('D', 'F'): 2.236, ('D', 'G'): 2.236, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0, ('E', 'F'): 1.0, ('E', 'G'): 2.236, ('F', 'A'): 1.0, ('F', 'B'): 2.236, ('F', 'C'): 2.0, ('F', 'D'): 2.236, ('F', 'E'): 1.0, ('F', 'F'): 0.0, ('F', 'G'): 1.414, ('G', 'A'): 1.0, ('G', 'B'): 1.0, ('G', 'C'): 1.414, ('G', 'D'): 2.236, ('G', 'E'): 2.236, ('G', 'F'): 1.414, ('G', 'G'): 0.0}
# ['G', 'A', 'C', 'B', 'D', 'E', 'F']
# 12.0
# ['B', 'C', 'A', 'F', 'E', 'D', 'G']
# 20.0

# %% [markdown]
# **5. Gloutonne Aléatoire - Setup**
#
# Avant de créer notre solution gloutonne aléatoire, nous définissons une fonction qui s'appelle kClosestNodes qui retournera les k noeuds les plus près du noeud spécifié.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Gloutonne Aléatoire**
#
# Maintenant vous allez trouver une autre solution sous-optimale. Cette deuxième solution sera la méthode gloutonne aléatoire.

# %% [markdown]
# **(TO DO) Q4 - 5 points**
#
# La méthode gloutonne aléatoire va dabord sélectionner un noeud initial aléatoire. Ensuite, l'algorithme va choisir aléatoirement un noeud parmis k noeuds disponibles en fonction d'une distribution de probabilités (au lieu du noeud le plus près).
#
# Par exemple, si vous observez les 5 noeuds voisins, vous allez choisir un noeud aléatoirement mais chacun des 5 noeuds aura une probabilité plus ou moins grande d'être sélectionné en fonction de sa distance.
#
# Cette distribution de probabilité est définie avec la fonction *normalize* ci-bas. Les k noeuds les plus près seront retournés par la fonction *kClosestNodes* ci-haut. Vous devez appeler ces deux fonctions dans votre solution puis suivre les instructions défini par les commentaires.
#
# Après avoir terminé, ajouter un autre test aux tests ci-bas avec des différentes valeurs de k.

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION #
def normalize(nodeFrom, nodesTo, distDict):
    """
    nodeFrom is the node we start at, nodesTo is a list of nodes
    that nodeFrom can go to, and distDict is the dictionary of all
    combinations of distances. This provides the probability distribution to be used by
    randomized_greedy_solution
    """
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# TO DO #
def randomized_greedy_solution(nodes, k):
    """
    k represents the number of closest nodes to be returned from the
    function kClosestNodes
    """
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        closest_nodes = kClosestNodes(cur_node, free_list, allDist, k)
        # Find the normalized distances
        normalized_distances = normalize(cur_node, closest_nodes, allDist)
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        found_node = np.random.choice( closest_nodes, p = normalized_distances)
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        print("Les neuds les plus proches " + ', '.join(map(str, closest_nodes)))
        print("Les distances normalisees: " + ', '.join(map(str, normalized_distances)))
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        print("Le noeud trouver est " + found_node + ",sa probabilite d'etre selectionner est " + str(normalized_distances[closest_nodes.index(found_node)]))
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)

# TO DO: Add one more test randomized_greedy_solution with a different k
print("Randomized Greedy Test")
rgs3 = randomized_greedy_solution(moreCities, 3)
print(rgs3)
print(totalDist(rgs3, moreDistances))
showPath(rgs3, moreCities)
# Out:
# Greedy Test
# ['F', 'A', 'C', 'B', 'G', 'D', 'E']
# 8.236
# Randomized Greedy Test
# Les neuds les plus proches A
# Les distances normalisees: 1.0
# Le noeud trouver est A,sa probabilite d'etre selectionner est 1.0
# Les neuds les plus proches C
# Les distances normalisees: 1.0
# Le noeud trouver est C,sa probabilite d'etre selectionner est 1.0
# Les neuds les plus proches B
# Les distances normalisees: 1.0
# Le noeud trouver est B,sa probabilite d'etre selectionner est 1.0
# Les neuds les plus proches D
# Les distances normalisees: 1.0
# Le noeud trouver est D,sa probabilite d'etre selectionner est 1.0
# Les neuds les plus proches E
# Les distances normalisees: 1.0
# Le noeud trouver est E,sa probabilite d'etre selectionner est 1.0
# Les neuds les plus proches F
# Les distances normalisees: 1.0
# Le noeud trouver est F,sa probabilite d'etre selectionner est 1.0
# ['G', 'A', 'C', 'B', 'D', 'E', 'F']
# 8.0
# Randomized Greedy Test
# Les neuds les plus proches A, B
# Les distances normalisees: 0.5, 0.5
# Le noeud trouver est A,sa probabilite d'etre selectionner est 0.5
# Les neuds les plus proches F, G
# Les distances normalisees: 0.5, 0.5
# Le noeud trouver est G,sa probabilite d'etre selectionner est 0.5
# Les neuds les plus proches B, F
# Les distances normalisees: 0.6665995420411309, 0.3334004579588691
# Le noeud trouver est F,sa probabilite d'etre selectionner est 0.3334004579588691
# Les neuds les plus proches E, B
# Les distances normalisees: 0.8333248884610154, 0.1666751115389846
# Le noeud trouver est E,sa probabilite d'etre selectionner est 0.8333248884610154
# Les neuds les plus proches D, B
# Les distances normalisees: 0.6665995420411309, 0.3334004579588691
# Le noeud trouver est D,sa probabilite d'etre selectionner est 0.6665995420411309
# Les neuds les plus proches B
# Les distances normalisees: 1.0
# Le noeud trouver est B,sa probabilite d'etre selectionner est 1.0
# ['C', 'A', 'G', 'F', 'E', 'D', 'B']
# 8.414
# Randomized Greedy Test
# Les neuds les plus proches A, B, C
# Les distances normalisees: 0.39997583416153343, 0.39997583416153343, 0.2000483316769332
# Le noeud trouver est A,sa probabilite d'etre selectionner est 0.39997583416153343
# Les neuds les plus proches C, F, B
# Les distances normalisees: 0.39997583416153343, 0.39997583416153343, 0.2000483316769332
# Le noeud trouver est C,sa probabilite d'etre selectionner est 0.39997583416153343
# Les neuds les plus proches B, D, F
# Les distances normalisees: 0.4444444444444444, 0.4444444444444444, 0.1111111111111111
# Le noeud trouver est B,sa probabilite d'etre selectionner est 0.4444444444444444
# Les neuds les plus proches D, F, E
# Les distances normalisees: 0.4347448636601914, 0.34781703820407583, 0.21743809813573273
# Le noeud trouver est D,sa probabilite d'etre selectionner est 0.4347448636601914
# Les neuds les plus proches E, F
# Les distances normalisees: 0.5555405427027759, 0.44445945729722425
# Le noeud trouver est F,sa probabilite d'etre selectionner est 0.44445945729722425
# Les neuds les plus proches E
# Les distances normalisees: 1.0
# Le noeud trouver est E,sa probabilite d'etre selectionner est 1.0
# ['G', 'A', 'C', 'B', 'D', 'F', 'E']
# 8.236

# %% [markdown]
# **7. Definissons le processus du recuit simulé**
# La classe ci-bas définit le processus du recuit simulé.  Cette classe est une adaptation de la classe *anneal.py* qui se trouve dans le code python du github https://github.com/chncyhn/simulated-annealing-tsp. Vous n'avez pas à modifier cette classe, mais tenter de la comprendre pour assimiler l'algorithme du recuit simulé.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refinement d'une solution gloutonne avec recuit simulé

# %% [markdown]
# **(TO DO) Q5 - 5 points**
# Ajoutez des commentaires au code ci-bas pour expliquer ce qui se passe.  Aussi exécuter le code quelques fois.  Cela vous montrera qu'il peut y avoir parfois un coût total plus bas en appliquant le recuit simulé.

# %%
# Trouver une greedy solution unique
firstSol = greedy_solution(moreCities)
# Construire le dictionnaire de distance
distances = distDict(moreCities)
# Affiche la solution et la distance total
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
# Montre le chemin unique de cette premiere solution
showPath(firstSol, moreCities)
# Initialise l'objet recuit simulé avec more cities et sans randomizedGreedy
sa = SimAnneal(moreCities, False)
# Execute l'algorithme de recuit simulé
betterSol = sa.anneal()
# Montre le chemin unique de cette meilleur solution
showPath(betterSol, moreCities)
# Trouver une randomized greedy solution avec une initialisation de k a 4
secondSol = randomized_greedy_solution(moreCities, 4)
# Affiche la solution et la distance total
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
# Montre le chemin unique de cette deuxieme solution
showPath(secondSol, moreCities)
# Initialise l'objet recuit simulé avec more cities et avec randomizedGreedy et avec une initialisation de k a 4
sa2 = SimAnneal(moreCities, True, 4)
# Execute l'algorithme de recuit simulé
betterSol2 = sa2.anneal()
# Montre le chemin unique de cette meilleur deuxieme solution
showPath(betterSol2, moreCities)
# Out:
# Solution ['C', 'A', 'F', 'E', 'D', 'B', 'G'] takes a total of 8.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.0
# Improvement over greedy heuristic:  0.2715
# Les neuds les plus proches C, A, B, E
# Les distances normalisees: 0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198
# Le noeud trouver est E,sa probabilite d'etre selectionner est 0.12499056036192198
# Les neuds les plus proches F, A, C, G
# Les distances normalisees: 0.5262672158144318, 0.26321309826289135, 0.10525984296133839, 0.10525984296133839
# Le noeud trouver est F,sa probabilite d'etre selectionner est 0.5262672158144318
# Les neuds les plus proches A, G, C, B
# Les distances normalisees: 0.5127775956090351, 0.2564662506122025, 0.12819439890225878, 0.1025617548765035
# Le noeud trouver est A,sa probabilite d'etre selectionner est 0.5127775956090351
# Les neuds les plus proches C, G, B
# Les distances normalisees: 0.39997583416153343, 0.39997583416153343, 0.2000483316769332
# Le noeud trouver est B,sa probabilite d'etre selectionner est 0.2000483316769332
# Les neuds les plus proches C, G
# Les distances normalisees: 0.5, 0.5
# Le noeud trouver est G,sa probabilite d'etre selectionner est 0.5
# Les neuds les plus proches C
# Les distances normalisees: 1.0
# Le noeud trouver est C,sa probabilite d'etre selectionner est 1.0
# Solution ['D', 'E', 'F', 'A', 'B', 'G', 'C'] takes a total of 7.828
# Les neuds les plus proches C, G, A, D
# Les distances normalisees: 0.3636163917593456, 0.3636163917593456, 0.18186311854147238, 0.0909040979398364
# Le noeud trouver est C,sa probabilite d'etre selectionner est 0.3636163917593456
# Les neuds les plus proches A, D, G, F
# Les distances normalisees: 0.3636163917593456, 0.3636163917593456, 0.18186311854147238, 0.0909040979398364
# Le noeud trouver est G,sa probabilite d'etre selectionner est 0.18186311854147238
# Les neuds les plus proches A, F, D, E
# Les distances normalisees: 0.5262672158144318, 0.26321309826289135, 0.10525984296133839, 0.10525984296133839
# Le noeud trouver est A,sa probabilite d'etre selectionner est 0.5262672158144318
# Les neuds les plus proches F, D, E
# Les distances normalisees: 0.4999244885977782, 0.25003775570111086, 0.25003775570111086
# Le noeud trouver est F,sa probabilite d'etre selectionner est 0.4999244885977782
# Les neuds les plus proches E, D
# Les distances normalisees: 0.8333248884610154, 0.1666751115389846
# Le noeud trouver est E,sa probabilite d'etre selectionner est 0.8333248884610154
# Les neuds les plus proches D
# Les distances normalisees: 1.0
# Le noeud trouver est D,sa probabilite d'etre selectionner est 1.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.0
# Improvement over randomized greedy heuristic:  0.1907

# %% [markdown]
# **9. Test à plus grande échelle**
# Le fichier *coord.txt* (que vous trouverez aussi sur Brightspace dans la section des Jupyter Notebooks), contient un ensemble de coordonnées. Ce fichier de données est aussi tiré du github https://github.com/chncyhn/simulated-annealing-tsp.  Voici le début du fichier.
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Nous utiliserons le chiffre de la première colonne comme étiquette de la ville (e.g. ville 0, ville 1, ...) et les deux autres colonnes comme les coordonnées.
#
# Assurez-vous de mettre le fichier *coord.txt* dans le même répertoire que votre notebook (ou sinon changer le chemin d'accès dans le code ci-bas).

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Visualisons où sont les noeuds pour cet exemple.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Nous pouvons maintenant tester le processus de *recuit simulé* sur ce plus grand exemple.  Le code test est très similaire au code que vous avez commenté à la question (5) ci-haut.  Regarder l'étape supplémentaire, *plot_learning*, qui montre la valeur de la fonction de coût au fur et à mesure de la progression de l'algorithme.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['11', '18', '19', '17', '3', '2', '16', '10', '25', '1', '22', '21', '9', '20', '26', '27', '23', '24', '45', '44', '43', '37', '39', '38', '40', '41', '35', '32', '33', '42', '31', '34', '30', '28', '7', '6', '8', '36', '4', '5', '15', '13', '14', '12', '29'] takes a total of 663.582
# 6.708203932499369
# 1e-08
# Best fitness obtained:  534.63
# Improvement over greedy heuristic:  0.1946
# Les neuds les plus proches 37, 39, 38
# Les distances normalisees: 0.4521427032053978, 0.3217511947862763, 0.2261061020083259
# Le noeud trouver est 39,sa probabilite d'etre selectionner est 0.3217511947862763
# Les neuds les plus proches 38, 37, 40
# Les distances normalisees: 0.9577689708016932, 0.03613240115069552, 0.006098628047611141
# Le noeud trouver est 37,sa probabilite d'etre selectionner est 0.03613240115069552
# Les neuds les plus proches 38, 40, 41
# Les distances normalisees: 0.5421973468574693, 0.23649670081110646, 0.22130595233142408
# Le noeud trouver est 38,sa probabilite d'etre selectionner est 0.5421973468574693
# Les neuds les plus proches 2, 10, 40
# Les distances normalisees: 0.34984635817904347, 0.3314078747850406, 0.3187457670359159
# Le noeud trouver est 40,sa probabilite d'etre selectionner est 0.3187457670359159
# Les neuds les plus proches 41, 35, 42
# Les distances normalisees: 0.9900053799006964, 0.006186663624807113, 0.003807956474496648
# Le noeud trouver est 41,sa probabilite d'etre selectionner est 0.9900053799006964
# Les neuds les plus proches 35, 42, 31
# Les distances normalisees: 0.5116568365331655, 0.27269175012092955, 0.21565141334590493
# Le noeud trouver est 35,sa probabilite d'etre selectionner est 0.5116568365331655
# Les neuds les plus proches 32, 33, 42
# Les distances normalisees: 0.4534060168040718, 0.32533254056755373, 0.2212614426283745
# Le noeud trouver est 33,sa probabilite d'etre selectionner est 0.32533254056755373
# Les neuds les plus proches 32, 42, 31
# Les distances normalisees: 0.9708995300059152, 0.014931761223890831, 0.014168708770194131
# Le noeud trouver est 32,sa probabilite d'etre selectionner est 0.9708995300059152
# Les neuds les plus proches 42, 31, 36
# Les distances normalisees: 0.42005438244990434, 0.3898103082913322, 0.19013530925876357
# Le noeud trouver est 36,sa probabilite d'etre selectionner est 0.19013530925876357
# Les neuds les plus proches 4, 5, 8
# Les distances normalisees: 0.38175445748525666, 0.32537049503057336, 0.29287504748416987
# Le noeud trouver est 8,sa probabilite d'etre selectionner est 0.29287504748416987
# Les neuds les plus proches 6, 7, 4
# Les distances normalisees: 0.5308094717752011, 0.4010870488585818, 0.06810347936621709
# Le noeud trouver est 6,sa probabilite d'etre selectionner est 0.5308094717752011
# Les neuds les plus proches 7, 28, 4
# Les distances normalisees: 0.992605828999194, 0.005143364132327101, 0.002250806868478898
# Le noeud trouver est 7,sa probabilite d'etre selectionner est 0.992605828999194
# Les neuds les plus proches 28, 4, 5
# Les distances normalisees: 0.5876467816261943, 0.20639204478724418, 0.2059611735865615
# Le noeud trouver est 4,sa probabilite d'etre selectionner est 0.20639204478724418
# Les neuds les plus proches 5, 42, 31
# Les distances normalisees: 0.9975656029200252, 0.0012579870339638265, 0.0011764100460108524
# Le noeud trouver est 5,sa probabilite d'etre selectionner est 0.9975656029200252
# Les neuds les plus proches 42, 31, 28
# Les distances normalisees: 0.37418903863406844, 0.3506158259076183, 0.2751951354583132
# Le noeud trouver est 28,sa probabilite d'etre selectionner est 0.2751951354583132
# Les neuds les plus proches 30, 34, 42
# Les distances normalisees: 0.7492965150803986, 0.16933194293590248, 0.0813715419836989
# Le noeud trouver est 34,sa probabilite d'etre selectionner est 0.16933194293590248
# Les neuds les plus proches 30, 31, 42
# Les distances normalisees: 0.3672351533080907, 0.3194988888343016, 0.31326595785760775
# Le noeud trouver est 42,sa probabilite d'etre selectionner est 0.31326595785760775
# Les neuds les plus proches 31, 44, 45
# Les distances normalisees: 0.9936371227484436, 0.0032579196055104592, 0.0031049576460459457
# Le noeud trouver est 31,sa probabilite d'etre selectionner est 0.9936371227484436
# Les neuds les plus proches 44, 45, 9
# Les distances normalisees: 0.4637846305541925, 0.444029043350007, 0.09218632609580053
# Le noeud trouver est 44,sa probabilite d'etre selectionner est 0.4637846305541925
# Les neuds les plus proches 45, 9, 10
# Les distances normalisees: 0.9966087204407744, 0.0021806729553888074, 0.0012106066038369214
# Le noeud trouver est 45,sa probabilite d'etre selectionner est 0.9966087204407744
# Les neuds les plus proches 9, 10, 22
# Les distances normalisees: 0.4962346549262992, 0.2589767899376976, 0.24478855513600314
# Le noeud trouver est 10,sa probabilite d'etre selectionner est 0.2589767899376976
# Les neuds les plus proches 16, 25, 1
# Les distances normalisees: 0.7433767939183448, 0.1285023299559744, 0.1281208761256809
# Le noeud trouver est 16,sa probabilite d'etre selectionner est 0.7433767939183448
# Les neuds les plus proches 25, 1, 2
# Les distances normalisees: 0.35829458233990713, 0.3565230420010415, 0.2851823756590514
# Le noeud trouver est 25,sa probabilite d'etre selectionner est 0.35829458233990713
# Les neuds les plus proches 1, 2, 17
# Les distances normalisees: 0.9999958708786932, 2.9502159356887242e-06, 1.1789053710899299e-06
# Le noeud trouver est 1,sa probabilite d'etre selectionner est 0.9999958708786932
# Les neuds les plus proches 2, 17, 3
# Les distances normalisees: 0.5587718469958128, 0.22349034058826894, 0.2177378124159181
# Le noeud trouver est 2,sa probabilite d'etre selectionner est 0.5587718469958128
# Les neuds les plus proches 3, 17, 22
# Les distances normalisees: 0.6845795182847563, 0.27132042840998516, 0.044100053305258693
# Le noeud trouver est 3,sa probabilite d'etre selectionner est 0.6845795182847563
# Les neuds les plus proches 17, 11, 18
# Les distances normalisees: 0.8656579537655131, 0.07111677375857699, 0.06322527247590985
# Le noeud trouver est 17,sa probabilite d'etre selectionner est 0.8656579537655131
# Les neuds les plus proches 11, 18, 22
# Les distances normalisees: 0.48232687400240604, 0.3318142075227794, 0.18585891847481464
# Le noeud trouver est 22,sa probabilite d'etre selectionner est 0.18585891847481464
# Les neuds les plus proches 21, 9, 20
# Les distances normalisees: 0.9979111344744157, 0.0011076083854185193, 0.0009812571401658075
# Le noeud trouver est 21,sa probabilite d'etre selectionner est 0.9979111344744157
# Les neuds les plus proches 9, 20, 11
# Les distances normalisees: 0.4104992472108747, 0.39200086077589613, 0.1974998920132292
# Le noeud trouver est 20,sa probabilite d'etre selectionner est 0.39200086077589613
# Les neuds les plus proches 26, 9, 11
# Les distances normalisees: 0.5152826346092628, 0.3709906302943768, 0.1137267350963603
# Le noeud trouver est 26,sa probabilite d'etre selectionner est 0.5152826346092628
# Les neuds les plus proches 27, 23, 24
# Les distances normalisees: 0.36240245774960184, 0.3274377370724676, 0.3101598051779306
# Le noeud trouver est 23,sa probabilite d'etre selectionner est 0.3274377370724676
# Les neuds les plus proches 24, 27, 9
# Les distances normalisees: 0.6664616157046437, 0.33333147395745705, 0.0002069103378992558
# Le noeud trouver est 27,sa probabilite d'etre selectionner est 0.33333147395745705
# Les neuds les plus proches 24, 9, 11
# Les distances normalisees: 0.9970019808891661, 0.001615775256221815, 0.0013822438546120775
# Le noeud trouver est 24,sa probabilite d'etre selectionner est 0.9970019808891661
# Les neuds les plus proches 9, 11, 19
# Les distances normalisees: 0.373979225458803, 0.32312908672376733, 0.3028916878174297
# Le noeud trouver est 9,sa probabilite d'etre selectionner est 0.373979225458803
# Les neuds les plus proches 11, 18, 19
# Les distances normalisees: 0.42796209393389256, 0.3051436363046927, 0.2668942697614147
# Le noeud trouver est 18,sa probabilite d'etre selectionner est 0.3051436363046927
# Les neuds les plus proches 11, 19, 12
# Les distances normalisees: 0.5217769328126872, 0.41974724995099405, 0.058475817236318825
# Le noeud trouver est 11,sa probabilite d'etre selectionner est 0.5217769328126872
# Les neuds les plus proches 19, 12, 13
# Les distances normalisees: 0.8670005041214947, 0.07790545622058183, 0.055094039657923616
# Le noeud trouver est 19,sa probabilite d'etre selectionner est 0.8670005041214947
# Les neuds les plus proches 12, 13, 15
# Les distances normalisees: 0.4746222274415471, 0.26516167498827187, 0.2602160975701811
# Le noeud trouver est 13,sa probabilite d'etre selectionner est 0.26516167498827187
# Les neuds les plus proches 15, 14, 12
# Les distances normalisees: 0.5537309011268946, 0.44301165601020104, 0.003257442862904444
# Le noeud trouver est 15,sa probabilite d'etre selectionner est 0.5537309011268946
# Les neuds les plus proches 14, 12, 30
# Les distances normalisees: 0.9934573535064813, 0.0064343293420259, 0.00010831715149277941
# Le noeud trouver est 14,sa probabilite d'etre selectionner est 0.9934573535064813
# Les neuds les plus proches 12, 30, 29
# Les distances normalisees: 0.9775041369553765, 0.016436599080867902, 0.006059263963755499
# Le noeud trouver est 12,sa probabilite d'etre selectionner est 0.9775041369553765
# Les neuds les plus proches 30, 29
# Les distances normalisees: 0.7081287652238161, 0.29187123477618393
# Le noeud trouver est 30,sa probabilite d'etre selectionner est 0.7081287652238161
# Les neuds les plus proches 29
# Les distances normalisees: 1.0
# Le noeud trouver est 29,sa probabilite d'etre selectionner est 1.0
# Solution ['43', '39', '37', '38', '40', '41', '35', '33', '32', '36', '8', '6', '7', '4', '5', '28', '34', '42', '31', '44', '45', '10', '16', '25', '1', '2', '3', '17', '22', '21', '20', '26', '23', '27', '24', '9', '18', '11', '19', '13', '15', '14', '12', '30', '29'] takes a total of 732.03
# Les neuds les plus proches 23, 27, 26, 20
# Les distances normalisees: 0.8320965053448661, 0.16642941997770785, 0.0009755050821517843, 0.0004985695952741922
# Le noeud trouver est 23,sa probabilite d'etre selectionner est 0.8320965053448661
# Les neuds les plus proches 27, 26, 20, 21
# Les distances normalisees: 0.9956099388132547, 0.002463695870459104, 0.001248815247576975, 0.0006775500687092941
# Le noeud trouver est 27,sa probabilite d'etre selectionner est 0.9956099388132547
# Les neuds les plus proches 26, 20, 21, 22
# Les distances normalisees: 0.49801017730398395, 0.2436785424984527, 0.1302169686404292, 0.12809431155713427
# Le noeud trouver est 22,sa probabilite d'etre selectionner est 0.12809431155713427
# Les neuds les plus proches 21, 1, 25, 10
# Les distances normalisees: 0.9934315392915514, 0.0024530665274116606, 0.0024486840959017987, 0.0016667100851353973
# Le noeud trouver est 21,sa probabilite d'etre selectionner est 0.9934315392915514
# Les neuds les plus proches 1, 25, 10, 16
# Les distances normalisees: 0.3029835256221443, 0.3025132369454457, 0.20555879192626197, 0.1889444455061482
# Le noeud trouver est 10,sa probabilite d'etre selectionner est 0.20555879192626197
# Les neuds les plus proches 16, 25, 1, 2
# Les distances normalisees: 0.7031675566501439, 0.12155164126487171, 0.12119082026532384, 0.05408998181966063
# Le noeud trouver est 1,sa probabilite d'etre selectionner est 0.12119082026532384
# Les neuds les plus proches 25, 16, 2, 17
# Les distances normalisees: 0.9999833790178426, 1.2503568315354272e-05, 2.9410790575421462e-06, 1.1763347845834558e-06
# Le noeud trouver est 25,sa probabilite d'etre selectionner est 0.9999833790178426
# Les neuds les plus proches 16, 2, 17, 3
# Les distances normalisees: 0.7042257089258004, 0.16533836770739263, 0.06606916035520076, 0.06436676301160642
# Le noeud trouver est 2,sa probabilite d'etre selectionner est 0.16533836770739263
# Les neuds les plus proches 16, 3, 17, 11
# Les distances normalisees: 0.5283436071855757, 0.32509822015583273, 0.1288466657445546, 0.017711506914036845
# Le noeud trouver est 16,sa probabilite d'etre selectionner est 0.5283436071855757
# Les neuds les plus proches 3, 17, 11, 38
# Les distances normalisees: 0.48778716398285604, 0.3696336560153716, 0.07621066342551126, 0.06636851657626094
# Le noeud trouver est 17,sa probabilite d'etre selectionner est 0.3696336560153716
# Les neuds les plus proches 3, 11, 18, 19
# Les distances normalisees: 0.7596766504055612, 0.12088115671790828, 0.08315954880960988, 0.03628264406692067
# Le noeud trouver est 3,sa probabilite d'etre selectionner est 0.7596766504055612
# Les neuds les plus proches 11, 18, 38, 39
# Les distances normalisees: 0.3210351591960753, 0.2854113641800432, 0.2091979143143635, 0.184355562309518
# Le noeud trouver est 11,sa probabilite d'etre selectionner est 0.3210351591960753
# Les neuds les plus proches 18, 19, 20, 26
# Les distances normalisees: 0.5211752727408231, 0.4023544882075238, 0.039941414514119686, 0.03652882453753335
# Le noeud trouver est 19,sa probabilite d'etre selectionner est 0.4023544882075238
# Les neuds les plus proches 18, 12, 13, 15
# Les distances normalisees: 0.7605708470330056, 0.1136383978956378, 0.0634874352417514, 0.062303319829605235
# Le noeud trouver est 18,sa probabilite d'etre selectionner est 0.7605708470330056
# Les neuds les plus proches 12, 13, 15, 14
# Les distances normalisees: 0.3249941585131191, 0.22987148175999594, 0.22921235240238488, 0.21592200732450023
# Le noeud trouver est 12,sa probabilite d'etre selectionner est 0.3249941585131191
# Les neuds les plus proches 13, 15, 14, 38
# Les distances normalisees: 0.3576085519370867, 0.31499256301392664, 0.30975304110752583, 0.017645843941460918
# Le noeud trouver est 13,sa probabilite d'etre selectionner est 0.3576085519370867
# Les neuds les plus proches 15, 14, 38, 39
# Les distances normalisees: 0.5553579340978996, 0.44431336153070067, 0.0001682412322777168, 0.00016046313912208214
# Le noeud trouver est 14,sa probabilite d'etre selectionner est 0.44431336153070067
# Les neuds les plus proches 15, 38, 39, 37
# Les distances normalisees: 0.9989479752317728, 0.0003704777930394634, 0.0003535922307123611, 0.00032795474447530685
# Le noeud trouver est 15,sa probabilite d'etre selectionner est 0.9989479752317728
# Les neuds les plus proches 38, 39, 37, 43
# Les distances normalisees: 0.2773215212764424, 0.2644339193937375, 0.24478586367582464, 0.2134586956539954
# Le noeud trouver est 39,sa probabilite d'etre selectionner est 0.2644339193937375
# Les neuds les plus proches 38, 43, 37, 40
# Les distances normalisees: 0.9237498585971928, 0.035519121251156215, 0.034849010013128554, 0.0058820101385223394
# Le noeud trouver est 38,sa probabilite d'etre selectionner est 0.9237498585971928
# Les neuds les plus proches 37, 43, 40, 41
# Les distances normalisees: 0.44827909391767184, 0.3937632642697459, 0.0809312560337024, 0.07702638577888
# Le noeud trouver est 43,sa probabilite d'etre selectionner est 0.3937632642697459
# Les neuds les plus proches 37, 40, 41, 42
# Les distances normalisees: 0.572903788770329, 0.1737744356940376, 0.15910357418653145, 0.09421820134910192
# Le noeud trouver est 40,sa probabilite d'etre selectionner est 0.1737744356940376
# Les neuds les plus proches 41, 35, 42, 31
# Les distances normalisees: 0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556
# Le noeud trouver est 41,sa probabilite d'etre selectionner est 0.9870259769962175
# Les neuds les plus proches 35, 42, 31, 32
# Les distances normalisees: 0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421
# Le noeud trouver est 31,sa probabilite d'etre selectionner est 0.18936859612906848
# Les neuds les plus proches 42, 32, 33, 35
# Les distances normalisees: 0.9783311876708553, 0.00782712539059059, 0.007140737401391317, 0.0067009495371629525
# Le noeud trouver est 42,sa probabilite d'etre selectionner est 0.9783311876708553
# Les neuds les plus proches 32, 35, 33, 44
# Les distances normalisees: 0.3124482818535576, 0.2899518875724566, 0.27877092369196277, 0.11882890688202304
# Le noeud trouver est 32,sa probabilite d'etre selectionner est 0.3124482818535576
# Les neuds les plus proches 33, 35, 36, 34
# Les distances normalisees: 0.9541854411298218, 0.03127732025905265, 0.007444875740592039, 0.007092362870533479
# Le noeud trouver est 33,sa probabilite d'etre selectionner est 0.9541854411298218
# Les neuds les plus proches 35, 34, 36, 4
# Les distances normalisees: 0.5478370453510893, 0.20698111416010467, 0.16557521231629457, 0.07960662817251132
# Le noeud trouver est 34,sa probabilite d'etre selectionner est 0.20698111416010467
# Les neuds les plus proches 30, 35, 36, 8
# Les distances normalisees: 0.33057499526846745, 0.27471106260120043, 0.21788117225670614, 0.17683276987362587
# Le noeud trouver est 30,sa probabilite d'etre selectionner est 0.33057499526846745
# Les neuds les plus proches 28, 7, 6, 8
# Les distances normalisees: 0.4911988211356352, 0.17676101936988645, 0.1699929262371831, 0.16204723325729534
# Le noeud trouver est 28,sa probabilite d'etre selectionner est 0.4911988211356352
# Les neuds les plus proches 7, 6, 8, 36
# Les distances normalisees: 0.37435176697759254, 0.3297404995219722, 0.20864808131750268, 0.08725965218293256
# Le noeud trouver est 8,sa probabilite d'etre selectionner est 0.20864808131750268
# Les neuds les plus proches 6, 7, 36, 4
# Les distances normalisees: 0.46154059170684986, 0.34874651583938177, 0.13049669184819435, 0.05921620060557399
# Le noeud trouver est 6,sa probabilite d'etre selectionner est 0.46154059170684986
# Les neuds les plus proches 7, 36, 4, 5
# Les distances normalisees: 0.9919795271379807, 0.0035268321510776345, 0.002249386682852564, 0.002244254028089221
# Le noeud trouver est 7,sa probabilite d'etre selectionner est 0.9919795271379807
# Les neuds les plus proches 36, 4, 5, 35
# Les distances normalisees: 0.3801332079210056, 0.2452520819222066, 0.24474008515839388, 0.12987462499839383
# Le noeud trouver est 5,sa probabilite d'etre selectionner est 0.24474008515839388
# Les neuds les plus proches 4, 36, 35, 37
# Les distances normalisees: 0.986068528083235, 0.00910974899418394, 0.0029612600884958667, 0.00186046283408531
# Le noeud trouver est 4,sa probabilite d'etre selectionner est 0.986068528083235
# Les neuds les plus proches 36, 35, 37, 44
# Les distances normalisees: 0.6470283689323378, 0.20030210807277157, 0.11820466287941404, 0.03446486011547655
# Le noeud trouver est 36,sa probabilite d'etre selectionner est 0.6470283689323378
# Les neuds les plus proches 35, 37, 44, 45
# Les distances normalisees: 0.6776647396499952, 0.17984273455564395, 0.07242707371198776, 0.07006545208237325
# Le noeud trouver est 35,sa probabilite d'etre selectionner est 0.6776647396499952
# Les neuds les plus proches 37, 44, 45, 9
# Les distances normalisees: 0.5320104401197399, 0.2047788512153893, 0.1954117600217334, 0.06779894864313744
# Le noeud trouver est 45,sa probabilite d'etre selectionner est 0.1954117600217334
# Les neuds les plus proches 44, 9, 37, 20
# Les distances normalisees: 0.9953387327402431, 0.002211906274896226, 0.0017966715459998245, 0.0006526894388607656
# Le noeud trouver est 44,sa probabilite d'etre selectionner est 0.9953387327402431
# Les neuds les plus proches 9, 37, 20, 26
# Les distances normalisees: 0.42493254365250915, 0.3815376912810573, 0.12693093211878254, 0.06659883294765123
# Le noeud trouver est 37,sa probabilite d'etre selectionner est 0.3815376912810573
# Les neuds les plus proches 9, 20, 26, 29
# Les distances normalisees: 0.5081045871800653, 0.268247913855141, 0.17326090427191357, 0.050386594692880135
# Le noeud trouver est 26,sa probabilite d'etre selectionner est 0.17326090427191357
# Les neuds les plus proches 20, 9, 29
# Les distances normalisees: 0.8171789178944441, 0.17304354236835207, 0.009777539737203765
# Le noeud trouver est 20,sa probabilite d'etre selectionner est 0.8171789178944441
# Les neuds les plus proches 9, 29
# Les distances normalisees: 0.9799502073835273, 0.02004979261647267
# Le noeud trouver est 9,sa probabilite d'etre selectionner est 0.9799502073835273
# Les neuds les plus proches 29
# Les distances normalisees: 1.0
# Le noeud trouver est 29,sa probabilite d'etre selectionner est 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  526.143
# Improvement over randomized greedy heuristic:  0.1961

# %% [markdown]
# **(TO DO) Q6 - 2 points**
# Tester le recuit simulé en variant certains paramètres, tel en faisant un changement sur les températures à explorer (T, stopping_T, alpha), ou encore sur le nombre d'itérations maximales à faire.  Ces paramètres sont tous des paramètres possibles à assigner à l'instantiation de la classe SimAnneal. Explorer 4 variations ci-bas.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, stopping_iter=100) means that I set a maximum of 100 iterations.
# Try a few variations and look at the differences

# Test 1 ... (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, alpha = 3)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 ... (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities,  True, T=-20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 ... (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False, stopping_T=-20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, stopping_iter=-20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# 1e-08
# Best fitness obtained:  595.39
# Improvement over greedy heuristic:  0.0
# Les neuds les plus proches 4, 5, 8, 35
# Les distances normalisees: 0.3166333622865689, 0.2698675858535445, 0.2429153326083497, 0.1705837192515369
# Le noeud trouver est 8,sa probabilite d'etre selectionner est 0.2429153326083497
# Les neuds les plus proches 6, 7, 4, 5
# Les distances normalisees: 0.49777900795008817, 0.37612876916975346, 0.0638656320195088, 0.06222659086064959
# Le noeud trouver est 7,sa probabilite d'etre selectionner est 0.37612876916975346
# Les neuds les plus proches 6, 28, 4, 5
# Les distances normalisees: 0.990088583255146, 0.005824412151469512, 0.0020456375687089795, 0.0020413670246756574
# Le noeud trouver est 6,sa probabilite d'etre selectionner est 0.990088583255146
# Les neuds les plus proches 28, 4, 5, 30
# Les distances normalisees: 0.4608792148251228, 0.20168708175794695, 0.2012268717954798, 0.13620683162145042
# Le noeud trouver est 4,sa probabilite d'etre selectionner est 0.20168708175794695
# Les neuds les plus proches 5, 35, 41, 40
# Les distances normalisees: 0.9921362892049441, 0.003329191629072614, 0.002289910479465375, 0.0022446086865177566
# Le noeud trouver est 5,sa probabilite d'etre selectionner est 0.9921362892049441
# Les neuds les plus proches 35, 41, 40, 37
# Les distances normalisees: 0.3305055151361577, 0.2330503888379185, 0.22879829356506384, 0.2076458024608599
# Le noeud trouver est 37,sa probabilite d'etre selectionner est 0.2076458024608599
# Les neuds les plus proches 43, 39, 38, 40
# Les distances normalisees: 0.39748410580767385, 0.2775189486185547, 0.22629231872834227, 0.09870462684542929
# Le noeud trouver est 39,sa probabilite d'etre selectionner est 0.2775189486185547
# Les neuds les plus proches 38, 43, 40, 41
# Les distances normalisees: 0.9516063927944765, 0.03659023331313028, 0.006059387612572882, 0.005743986279820387
# Le noeud trouver est 38,sa probabilite d'etre selectionner est 0.9516063927944765
# Les neuds les plus proches 43, 2, 10, 40
# Les distances normalisees: 0.6079702716065054, 0.13715017277638358, 0.1299217391394447, 0.12495781647766617
# Le noeud trouver est 43,sa probabilite d'etre selectionner est 0.6079702716065054
# Les neuds les plus proches 40, 41, 42, 31
# Les distances normalisees: 0.3380935415497972, 0.30955008229556846, 0.18330984788036178, 0.1690465282742725
# Le noeud trouver est 31,sa probabilite d'etre selectionner est 0.1690465282742725
# Les neuds les plus proches 42, 41, 40, 32
# Les distances normalisees: 0.9685192451611889, 0.011919914695735598, 0.011812215065381344, 0.007748625077694236
# Le noeud trouver est 42,sa probabilite d'etre selectionner est 0.9685192451611889
# Les neuds les plus proches 41, 40, 32, 35
# Les distances normalisees: 0.32715346462068273, 0.3234307838814053, 0.18123227175071518, 0.16818347974719688
# Le noeud trouver est 40,sa probabilite d'etre selectionner est 0.3234307838814053
# Les neuds les plus proches 41, 35, 32, 33
# Les distances normalisees: 0.9905372636891259, 0.006189987431074542, 0.0018074570696085218, 0.0014652918101910146
# Le noeud trouver est 41,sa probabilite d'etre selectionner est 0.9905372636891259
# Les neuds les plus proches 35, 32, 33, 44
# Les distances normalisees: 0.639941601509271, 0.17359032556833948, 0.13936505988424128, 0.04710301303814827
# Le noeud trouver est 35,sa probabilite d'etre selectionner est 0.639941601509271
# Les neuds les plus proches 32, 33, 34, 44
# Les distances normalisees: 0.5245899180570917, 0.3764091442822375, 0.05516972715894191, 0.04383121050172894
# Le noeud trouver est 32,sa probabilite d'etre selectionner est 0.5245899180570917
# Les neuds les plus proches 33, 34, 44, 45
# Les distances normalisees: 0.9877715749853028, 0.007342005171132123, 0.0024780086568047845, 0.0024084111867605246
# Le noeud trouver est 33,sa probabilite d'etre selectionner est 0.9877715749853028
# Les neuds les plus proches 34, 44, 45, 30
# Les distances normalisees: 0.5651994256074246, 0.1534053700547937, 0.14960914410991105, 0.1317860602278706
# Le noeud trouver est 34,sa probabilite d'etre selectionner est 0.5651994256074246
# Les neuds les plus proches 30, 28, 44, 45
# Les distances normalisees: 0.47288080785970354, 0.22791498065401622, 0.14974775235799917, 0.14945645912828098
# Le noeud trouver est 45,sa probabilite d'etre selectionner est 0.14945645912828098
# Les neuds les plus proches 44, 9, 10, 22
# Les distances normalisees: 0.9955417113152317, 0.002212357347047765, 0.0011545932921968247, 0.001091338045523596
# Le noeud trouver est 44,sa probabilite d'etre selectionner est 0.9955417113152317
# Les neuds les plus proches 9, 10, 16, 22
# Les distances normalisees: 0.3870278892262126, 0.21485959983521621, 0.2000912782322739, 0.1980212327062973
# Le noeud trouver est 9,sa probabilite d'etre selectionner est 0.3870278892262126
# Les neuds les plus proches 22, 21, 20, 1
# Les distances normalisees: 0.3208598017326183, 0.31018746115399987, 0.22236470469451144, 0.14658803241887047
# Le noeud trouver est 21,sa probabilite d'etre selectionner est 0.31018746115399987
# Les neuds les plus proches 22, 1, 25, 10
# Les distances normalisees: 0.9937266220420695, 0.0023435264831398288, 0.002339888879523259, 0.0015899625952673112
# Le noeud trouver est 22,sa probabilite d'etre selectionner est 0.9937266220420695
# Les neuds les plus proches 1, 25, 10, 16
# Les distances normalisees: 0.3032303412563547, 0.3026886167709327, 0.2060266455244821, 0.18805439644823077
# Le noeud trouver est 1,sa probabilite d'etre selectionner est 0.3032303412563547
# Les neuds les plus proches 25, 10, 16, 2
# Les distances normalisees: 0.9999707671244443, 1.3788422972300652e-05, 1.2503410619062514e-05, 2.941041964350071e-06
# Le noeud trouver est 25,sa probabilite d'etre selectionner est 0.9999707671244443
# Les neuds les plus proches 10, 16, 2, 17
# Les distances normalisees: 0.4530684262871687, 0.41166053107687967, 0.09664980899608289, 0.03862123363986865
# Le noeud trouver est 10,sa probabilite d'etre selectionner est 0.4530684262871687
# Les neuds les plus proches 16, 2, 3, 17
# Les distances normalisees: 0.8998562873484769, 0.0692199316687238, 0.017574249532933718, 0.013349531449865507
# Le noeud trouver est 16,sa probabilite d'etre selectionner est 0.8998562873484769
# Les neuds les plus proches 2, 3, 17, 11
# Les distances normalisees: 0.7201779452122943, 0.1461964479006341, 0.1107842344450693, 0.02284137244200241
# Le noeud trouver est 2,sa probabilite d'etre selectionner est 0.7201779452122943
# Les neuds les plus proches 3, 17, 11, 18
# Les distances normalisees: 0.6702166707113564, 0.2656279794647317, 0.036513725579663, 0.027641624244248854
# Le noeud trouver est 18,sa probabilite d'etre selectionner est 0.027641624244248854
# Les neuds les plus proches 11, 19, 17, 3
# Les distances normalisees: 0.3942056002989558, 0.3171215633255454, 0.1731474962950999, 0.1155253400803989
# Le noeud trouver est 19,sa probabilite d'etre selectionner est 0.3171215633255454
# Les neuds les plus proches 11, 17, 3, 12
# Les distances normalisees: 0.6339035953196468, 0.15735422104408833, 0.11004913179780614, 0.09869305183845871
# Le noeud trouver est 11,sa probabilite d'etre selectionner est 0.6339035953196468
# Les neuds les plus proches 17, 3, 20, 26
# Les distances normalisees: 0.5727040673550812, 0.29568286737886473, 0.06874323999058715, 0.06286982527546695
# Le noeud trouver est 17,sa probabilite d'etre selectionner est 0.5727040673550812
# Les neuds les plus proches 3, 20, 26, 12
# Les distances normalisees: 0.9570964436036444, 0.01812973602282037, 0.012809981904336104, 0.011963838469199017
# Le noeud trouver est 3,sa probabilite d'etre selectionner est 0.9570964436036444
# Les neuds les plus proches 20, 26, 12, 15
# Les distances normalisees: 0.33776358936537376, 0.22821956064692153, 0.22606359817086627, 0.20795325181683844
# Le noeud trouver est 20,sa probabilite d'etre selectionner est 0.33776358936537376
# Les neuds les plus proches 26, 27, 23, 24
# Les distances normalisees: 0.6925961455384683, 0.10862583586639163, 0.10167232478637267, 0.09710569380876757
# Le noeud trouver est 27,sa probabilite d'etre selectionner est 0.10862583586639163
# Les neuds les plus proches 23, 24, 26, 12
# Les distances normalisees: 0.712802100348441, 0.2850520648111947, 0.0019522221995874904, 0.00019361264077666091
# Le noeud trouver est 23,sa probabilite d'etre selectionner est 0.712802100348441
# Les neuds les plus proches 24, 26, 12, 13
# Les distances normalisees: 0.9985284340057, 0.0012358321513039994, 0.000131644860462059, 0.00010408898253383403
# Le noeud trouver est 24,sa probabilite d'etre selectionner est 0.9985284340057
# Les neuds les plus proches 26, 12, 13, 15
# Les distances normalisees: 0.7770381815774249, 0.086641876744881, 0.06847169588491164, 0.06784824579278252
# Le noeud trouver est 12,sa probabilite d'etre selectionner est 0.086641876744881
# Les neuds les plus proches 13, 15, 14, 26
# Les distances normalisees: 0.3585789628154311, 0.31584733063089365, 0.310593590694673, 0.01498011585900234
# Le noeud trouver est 13,sa probabilite d'etre selectionner est 0.3585789628154311
# Les neuds les plus proches 15, 14, 26, 28
# Les distances normalisees: 0.5554517519556341, 0.44438842038046633, 0.00010399812106715186, 5.58295428324064e-05
# Le noeud trouver est 14,sa probabilite d'etre selectionner est 0.44438842038046633
# Les neuds les plus proches 15, 26, 28, 30
# Les distances normalisees: 0.9995403263731444, 0.00022701964171683775, 0.0001256098161759987, 0.00010704416896276614
# Le noeud trouver est 15,sa probabilite d'etre selectionner est 0.9995403263731444
# Les neuds les plus proches 26, 28, 30, 29
# Les distances normalisees: 0.4560095039701343, 0.2512986315873869, 0.2141639433934028, 0.07852792104907598
# Le noeud trouver est 26,sa probabilite d'etre selectionner est 0.4560095039701343
# Les neuds les plus proches 30, 28, 29
# Les distances normalisees: 0.38152991245207774, 0.3709437077877194, 0.24752637976020297
# Le noeud trouver est 30,sa probabilite d'etre selectionner est 0.38152991245207774
# Les neuds les plus proches 28, 29
# Les distances normalisees: 0.974547926355012, 0.025452073644988093
# Le noeud trouver est 28,sa probabilite d'etre selectionner est 0.974547926355012
# Les neuds les plus proches 29
# Les distances normalisees: 1.0
# Le noeud trouver est 29,sa probabilite d'etre selectionner est 1.0
# -20
# 1e-08
# Best fitness obtained:  774.024
# Improvement over randomized greedy heuristic:  0.0
# 6.708203932499369
# -20
# Best fitness obtained:  504.064
# Improvement over greedy heuristic:  0.2033
# Les neuds les plus proches 38, 43, 37, 40
# Les distances normalisees: 0.9237498585971928, 0.035519121251156215, 0.034849010013128554, 0.0058820101385223394
# Le noeud trouver est 38,sa probabilite d'etre selectionner est 0.9237498585971928
# Les neuds les plus proches 37, 43, 2, 10
# Les distances normalisees: 0.4416471203819449, 0.38793781404596633, 0.08751371688340219, 0.08290134868868666
# Le noeud trouver est 43,sa probabilite d'etre selectionner est 0.38793781404596633
# Les neuds les plus proches 37, 40, 41, 42
# Les distances normalisees: 0.572903788770329, 0.1737744356940376, 0.15910357418653145, 0.09421820134910192
# Le noeud trouver est 40,sa probabilite d'etre selectionner est 0.1737744356940376
# Les neuds les plus proches 41, 35, 42, 31
# Les distances normalisees: 0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556
# Le noeud trouver est 41,sa probabilite d'etre selectionner est 0.9870259769962175
# Les neuds les plus proches 35, 42, 31, 32
# Les distances normalisees: 0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421
# Le noeud trouver est 42,sa probabilite d'etre selectionner est 0.23945706218743762
# Les neuds les plus proches 31, 32, 35, 33
# Les distances normalisees: 0.9762634431722915, 0.00841657931797801, 0.007810582428790003, 0.007509395080940447
# Le noeud trouver est 31,sa probabilite d'etre selectionner est 0.9762634431722915
# Les neuds les plus proches 32, 33, 35, 44
# Les distances normalisees: 0.31284394384467146, 0.28540956470378587, 0.267831595393926, 0.13391489605761678
# Le noeud trouver est 44,sa probabilite d'etre selectionner est 0.13391489605761678
# Les neuds les plus proches 45, 9, 37, 35
# Les distances normalisees: 0.9945077826172924, 0.0021760759072207013, 0.0019538512408507455, 0.001362290234636188
# Le noeud trouver est 45,sa probabilite d'etre selectionner est 0.9945077826172924
# Les neuds les plus proches 9, 37, 35, 32
# Les distances normalisees: 0.33907068355989994, 0.2754179307454444, 0.19944423026725636, 0.18606715542739943
# Le noeud trouver est 37,sa probabilite d'etre selectionner est 0.2754179307454444
# Les neuds les plus proches 35, 4, 5, 32
# Les distances normalisees: 0.3866090661075839, 0.21512558869793363, 0.20496958651832634, 0.1932957586761561
# Le noeud trouver est 4,sa probabilite d'etre selectionner est 0.21512558869793363
# Les neuds les plus proches 5, 36, 8, 35
# Les distances normalisees: 0.9823486861740709, 0.01064807080268276, 0.003706894468692375, 0.0032963485545539095
# Le noeud trouver est 5,sa probabilite d'etre selectionner est 0.9823486861740709
# Les neuds les plus proches 36, 8, 35, 6
# Les distances normalisees: 0.5081487389308527, 0.20222967640069928, 0.16518134369850856, 0.12444024096993966
# Le noeud trouver est 36,sa probabilite d'etre selectionner est 0.5081487389308527
# Les neuds les plus proches 8, 35, 32, 6
# Les distances normalisees: 0.38475647499200083, 0.27018957513096253, 0.1805544801048032, 0.1644994697722334
# Le noeud trouver est 35,sa probabilite d'etre selectionner est 0.27018957513096253
# Les neuds les plus proches 32, 33, 8, 34
# Les distances normalisees: 0.5175435751215787, 0.371353179950138, 0.05667456292449856, 0.054428682003784576
# Le noeud trouver est 32,sa probabilite d'etre selectionner est 0.5175435751215787
# Les neuds les plus proches 33, 34, 8, 6
# Les distances normalisees: 0.9871335901325771, 0.0073372630949209445, 0.0033115586185429044, 0.0022175881539592893
# Le noeud trouver est 33,sa probabilite d'etre selectionner est 0.9871335901325771
# Les neuds les plus proches 34, 8, 6, 7
# Les distances normalisees: 0.5379256414387863, 0.1984180567359901, 0.13448141035969657, 0.12917489146552702
# Le noeud trouver est 34,sa probabilite d'etre selectionner est 0.5379256414387863
# Les neuds les plus proches 30, 8, 28, 6
# Les distances normalisees: 0.4089441616032654, 0.2187543820766742, 0.19709935174200063, 0.17520210457805988
# Le noeud trouver est 8,sa probabilite d'etre selectionner est 0.2187543820766742
# Les neuds les plus proches 6, 7, 28, 30
# Les distances normalisees: 0.5217223343793871, 0.39422068095359636, 0.058161830477708946, 0.025895154189307705
# Le noeud trouver est 6,sa probabilite d'etre selectionner est 0.5217223343793871
# Les neuds les plus proches 7, 28, 30, 3
# Les distances normalisees: 0.9931110769399708, 0.005145982164642248, 0.0015208278084147748, 0.0002221130869720631
# Le noeud trouver est 7,sa probabilite d'etre selectionner est 0.9931110769399708
# Les neuds les plus proches 28, 30, 3, 2
# Les distances normalisees: 0.7437883932592635, 0.20133033540539508, 0.02745478459605894, 0.027426486739282347
# Le noeud trouver est 30,sa probabilite d'etre selectionner est 0.20133033540539508
# Les neuds les plus proches 28, 2, 10, 16
# Les distances normalisees: 0.9041878598265543, 0.03211869683543942, 0.032081682143609916, 0.031611761194396584
# Le noeud trouver est 2,sa probabilite d'etre selectionner est 0.03211869683543942
# Les neuds les plus proches 16, 3, 10, 25
# Les distances normalisees: 0.3959450792242144, 0.24363130126800273, 0.24363130126800273, 0.1167923182397802
# Le noeud trouver est 10,sa probabilite d'etre selectionner est 0.24363130126800273
# Les neuds les plus proches 16, 25, 1, 3
# Les distances normalisees: 0.7327387496858936, 0.12666340589858063, 0.12628741083798847, 0.014310433577537359
# Le noeud trouver est 16,sa probabilite d'etre selectionner est 0.7327387496858936
# Les neuds les plus proches 25, 1, 3, 17
# Les distances normalisees: 0.4387751141243291, 0.4366056484034543, 0.07089595098052817, 0.05372328649168847
# Le noeud trouver est 1,sa probabilite d'etre selectionner est 0.4366056484034543
# Les neuds les plus proches 25, 17, 3, 22
# Les distances normalisees: 0.9999966898666743, 1.176350442858205e-06, 1.1460717782622889e-06, 9.877111045553293e-07
# Le noeud trouver est 25,sa probabilite d'etre selectionner est 0.9999966898666743
# Les neuds les plus proches 17, 3, 22, 21
# Les distances normalisees: 0.277047910084104, 0.2699092447273796, 0.23170155415332838, 0.22134129103518796
# Le noeud trouver est 22,sa probabilite d'etre selectionner est 0.23170155415332838
# Les neuds les plus proches 21, 9, 20, 17
# Les distances normalisees: 0.9971578785625445, 0.0011067723264393857, 0.0009805164552326897, 0.0007548326557835228
# Le noeud trouver est 21,sa probabilite d'etre selectionner est 0.9971578785625445
# Les neuds les plus proches 9, 20, 17, 3
# Les distances normalisees: 0.3060579267282378, 0.2922659944931004, 0.21414591886596637, 0.18753015991269534
# Le noeud trouver est 17,sa probabilite d'etre selectionner est 0.21414591886596637
# Les neuds les plus proches 3, 11, 18, 19
# Les distances normalisees: 0.7596766504055612, 0.12088115671790828, 0.08315954880960988, 0.03628264406692067
# Le noeud trouver est 11,sa probabilite d'etre selectionner est 0.12088115671790828
# Les neuds les plus proches 18, 19, 3, 20
# Les distances normalisees: 0.4590761480702806, 0.3544131087296516, 0.15132843183062783, 0.035182311369440014
# Le noeud trouver est 19,sa probabilite d'etre selectionner est 0.3544131087296516
# Les neuds les plus proches 18, 3, 12, 13
# Les distances normalisees: 0.7145463192418697, 0.1190462874104877, 0.10676178196631206, 0.05964561138133052
# Le noeud trouver est 18,sa probabilite d'etre selectionner est 0.7145463192418697
# Les neuds les plus proches 3, 12, 13, 15
# Les distances normalisees: 0.5201248438215282, 0.19890447637919942, 0.14068704164766394, 0.1402836381516085
# Le noeud trouver est 3,sa probabilite d'etre selectionner est 0.5201248438215282
# Les neuds les plus proches 9, 20, 26, 12
# Les distances normalisees: 0.3485903306611879, 0.2777897498700519, 0.1876965329113141, 0.18592338655744603
# Le noeud trouver est 12,sa probabilite d'etre selectionner est 0.18592338655744603
# Les neuds les plus proches 13, 15, 14, 26
# Les distances normalisees: 0.3585789628154311, 0.31584733063089365, 0.310593590694673, 0.01498011585900234
# Le noeud trouver est 13,sa probabilite d'etre selectionner est 0.3585789628154311
# Les neuds les plus proches 15, 14, 26, 20
# Les distances normalisees: 0.5554252562881545, 0.44436722255765504, 0.0001039931602408972, 0.00010352799394959262
# Le noeud trouver est 15,sa probabilite d'etre selectionner est 0.5554252562881545
# Les neuds les plus proches 14, 20, 26, 9
# Les distances normalisees: 0.9993125849314027, 0.0002322535555173908, 0.0002319940773397407, 0.00022316743574013318
# Le noeud trouver est 14,sa probabilite d'etre selectionner est 0.9993125849314027
# Les neuds les plus proches 26, 20, 9, 27
# Les distances normalisees: 0.2833340216716331, 0.28256408744199357, 0.2708313387483688, 0.16327055213800457
# Le noeud trouver est 9,sa probabilite d'etre selectionner est 0.2708313387483688
# Les neuds les plus proches 20, 26, 27, 23
# Les distances normalisees: 0.6665020533506345, 0.1960298917967239, 0.0702162972733296, 0.0672517575793122
# Le noeud trouver est 20,sa probabilite d'etre selectionner est 0.6665020533506345
# Les neuds les plus proches 26, 27, 23, 24
# Les distances normalisees: 0.6925961455384683, 0.10862583586639163, 0.10167232478637267, 0.09710569380876757
# Le noeud trouver est 26,sa probabilite d'etre selectionner est 0.6925961455384683
# Les neuds les plus proches 27, 23, 24, 28
# Les distances normalisees: 0.3552014898216433, 0.3209315211441769, 0.3039969032387519, 0.019870085795427976
# Le noeud trouver est 24,sa probabilite d'etre selectionner est 0.3039969032387519
# Les neuds les plus proches 23, 27, 28, 29
# Les distances normalisees: 0.8332595983393678, 0.16666205272067894, 4.1702694819477136e-05, 3.66462451337699e-05
# Le noeud trouver est 23,sa probabilite d'etre selectionner est 0.8332595983393678
# Les neuds les plus proches 27, 28, 29
# Les distances normalisees: 0.9998096159602594, 0.00010140015248476812, 8.898388725576545e-05
# Le noeud trouver est 27,sa probabilite d'etre selectionner est 0.9998096159602594
# Les neuds les plus proches 28, 29
# Les distances normalisees: 0.5355200847705821, 0.4644799152294179
# Le noeud trouver est 29,sa probabilite d'etre selectionner est 0.4644799152294179
# Les neuds les plus proches 28
# Les distances normalisees: 1.0
# Le noeud trouver est 28,sa probabilite d'etre selectionner est 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  825.98
# Improvement over randomized greedy heuristic:  0.0

# %% [markdown]
# #### Signature
#
# Je, Valentin Magot 8843488, déclare que les réponses inscrites dans ce notebook sont les miennes.
