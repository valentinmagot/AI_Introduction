# %% [markdown]
# # Notebook 3 - Simulated annealing for the TSP

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2020
# Prepared by Julian Templeton and Caroline Barrière

# %% [markdown]
# ***INTRODUCTION***:
#
# This homework will allow you to look deeper into one of the randomized searches presented in class, that of *Simulated Annealing*. It is a good example of a *random modification* algorithm, in which we start with a greedy solution, and then make changes and accept the modified solutions with different probabilities given their level of fitness to a cost function.
#
# The application domain for experimenting with *Simulated Annealing* is the traveling salesman problem (TSP), which is a classical problem of scheduling, with optimization on the cost of travel.
#
# The notebook will lead into the **Simulated Annealing** portion after exploring a **greedy approach** and a **randomized greedy approach**.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (see the added step at the end), and submit it.
#
# *The notebook will be marked on 20.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %% [markdown]
# **1. Let's start with a small set of cities.**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# Let's plot the nodes using the *showNodes* method below.
# The packages matplotlib, networkx, and numpy must be installed first.
# To do so, open a command prompt and type **pip install numpy** and **pip install networkx** (If you are using linux or potentially Mac, you may need to use **pip3** rather than **pip** depending on how you set it up). You should already have matplotlib, but if not use the pip command **pip install matplotlib**. After installing the packages, run the cell below. If it does not work, restart the Kernel and run through it again to be able to run the cell.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Let's find the distances between all cities.
# First, we define a method to calculate the distance between two specific cities, and then a method to find the distances between all pairs of nodes.

# %%
import math

# returns the euclidian distance between two nodes
def dist(node1, node2):
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
# building a dictionary of all pairs or distances
def distDict(nodes):
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# and the precalculated distances between all nodes
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Greedy solution first
# Before we can apply *simulated annealing*, we must first find a suboptimal solution that we will refine. The first solution will be a Greedy solution. Only the choice of the starting node is random in this solution, and from there, the algorithm always choses the closest node.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# #### 4. Showing a path.
# We slightly modify to showNodes method from before, to become showPath, wich is now a directed graph.

# %%
# small method to show a path
# it receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E']
# and a dictionary of all the nodes and their positions
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 marks**
# 1. Select a seed (integer) to use in the cell below
# 2. Run that cell to set the seed (only once)
# 3. Run the tests below the seed declaration repeatedly (just manually run it) until you get two identical results in the same run. Record how many runs it took and the solution found in the answer section below.
# 4. Run the tests below the seed declaration repeatedly (just manually run it) until you get two different results in the same run. Record how many runs it took and the solution found in the answer section below.

# %% [markdown]
# **(ANSWER in this Markdown) Q1**
# Nb of runs needed to generate an identical gs1 and gs2 :  8
#
# Solution generated for the identical gs1 and gs2 : ['D', 'C', 'A', 'B', 'E']
#
# Nb of runs needed to generate a different gs1 and gs2 : 2
#
# Solutions generated for the distinct gs1 and gs2 : ['E', 'A', 'C', 'B', 'D'], ['B', 'C', 'A', 'D', 'E']

# %% [markdown]
# Setup the seed:

# %%
# To Do: Place your seed here and run the cell to set/reset it
# random.seed(int)
random.seed(8)

# %% [markdown]
# Let us run a test to visualize two greedy solutions. Look at the text output of the path if the plotted graph contains edges that go through a node.

# %%
# To Do: Need to run this (make no changes) and answer the questions above

# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['B', 'C', 'A', 'D', 'E']
# ['C', 'A', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 marks**
# Complete the method to find the total length of the path found.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i+1]
        total += distances.get((x,y), total)
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 5.414
# 6.414

# %% [markdown]
# **(TO DO) Q3 - 4 marks**
# Add two more cities (wherever you want within the predefined -2 to +2 axis as long as no other node is already there).  Rerun the full sequence of tasks performed above on the larger set of cities that you will define below: (1) defining the graph (2) showing the points (3) building the distance dictionary, (4) finding two unique greedy solutions, (5) showing the different paths found along with their total distances.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (-1, 1), 'G': (-1, 0)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
# (4) Find two unique greedy solutions 
gs3 = greedy_solution(moreCities)
gs4 = greedy_solution(moreCities)
# (5) Show the two unique paths found above along with their total distances
showPath(gs3, moreCities)
print(totalDist(gs3, moreDistances))
showPath(gs4, moreCities)
print(totalDist(gs4, moreDistances))
# Out:
# 32.0
# 20.0

# %% [markdown]
# **5. Randomized Greedy - Setup**
#
# Before we create our Randomized Greedy solution, we will define a new function called kClosestNodes that will return the k-closest nodes to a given node.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Randomized Greedy**
#
# Next you will find another suboptimal solution that we will refine. This second solution will be a Randomized Greedy solution.

# %% [markdown]
# **(TO DO) Q4 - 5 marks**
# The Randomized Greedy solution that you will create still selects a random first node, but should now pick randomly among the k closest nodes available, given a probability distribution (rather than the closest node).
#
# For example, if you found the five closest nodes when looking for which to add next, you would randomly choose one of them where the closest nodes would have a higher probability of being chosen then the nodes that are not as close.
#
# The probability distribution for a set of node distances is given by the function *normalize* below and finding the k-closest nodes is given from the kClosestNodes function above. You must call both of these functions in your solution and follow the general structure defined by the comments.
#
# After finishing the function, add one more test to the tests below with a different value for k

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION
# nodeFrom is the node we start at, nodesTo is a list of nodes
# that nodeFrom can go to, and distDict is the dictionary of all
# combinations of distances.
# This provides the probability distribution to be used by
# randomized_greedy_solution
def normalize(nodeFrom, nodesTo, distDict):
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# k represents the number of closest nodes to be returned from the
# function kClosestNodes
def randomized_greedy_solution(nodes, k):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        closestNodes = kClosestNodes(cur_node, free_list, allDist, k)
        # Find the normalized distances
        normalizedDistances = normalize(cur_node, closestNodes, allDist)
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        found_node = np.random.choice(closestNodes, p=normalizedDistances)
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        print("Closest nodes are: " + ', '.join(map(str, closestNodes)))
        print("The normalized distances are: " + ', '.join(map(str, normalizedDistances)))
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        print("The found node is " + found_node + " and its probablity of being selected is " + str(normalizedDistances[closestNodes.index(found_node)]))
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)
# TO DO: Add one more test randomized_greedy_solution with a different k
print("Randomized Greedy Test")
rgs3 = randomized_greedy_solution(moreCities, 3)
print(rgs3)
print(totalDist(rgs3, moreDistances))
showPath(rgs3, moreCities)
# Out:
# Greedy Test
# ['A', 'C', 'B', 'D', 'E', 'G', 'F']
# 8.0
# Randomized Greedy Test
# Closest nodes are: G
# The normalized distances are: 1.0
# The found node is G and its probablity of being selected is 1.0
# Closest nodes are: A
# The normalized distances are: 1.0
# The found node is A and its probablity of being selected is 1.0
# Closest nodes are: C
# The normalized distances are: 1.0
# The found node is C and its probablity of being selected is 1.0
# Closest nodes are: B
# The normalized distances are: 1.0
# The found node is B and its probablity of being selected is 1.0
# Closest nodes are: D
# The normalized distances are: 1.0
# The found node is D and its probablity of being selected is 1.0
# Closest nodes are: E
# The normalized distances are: 1.0
# The found node is E and its probablity of being selected is 1.0
# ['F', 'G', 'A', 'C', 'B', 'D', 'E']
# 8.0
# Randomized Greedy Test
# Closest nodes are: A, B
# The normalized distances are: 0.5, 0.5
# The found node is B and its probablity of being selected is 0.5
# Closest nodes are: A, D
# The normalized distances are: 0.6667337845343099, 0.3332662154656902
# The found node is D and its probablity of being selected is 0.3332662154656902
# Closest nodes are: A, E
# The normalized distances are: 0.6667337845343099, 0.3332662154656902
# The found node is E and its probablity of being selected is 0.3332662154656902
# Closest nodes are: G, A
# The normalized distances are: 0.6665995420411309, 0.3334004579588691
# The found node is G and its probablity of being selected is 0.6665995420411309
# Closest nodes are: A, F
# The normalized distances are: 0.5, 0.5
# The found node is F and its probablity of being selected is 0.5
# Closest nodes are: A
# The normalized distances are: 1.0
# The found node is A and its probablity of being selected is 1.0
# ['C', 'B', 'D', 'E', 'G', 'F', 'A']
# 8.414
# Randomized Greedy Test
# Closest nodes are: G, A, D
# The normalized distances are: 0.5713792546677926, 0.2857759316652593, 0.14284481366694815
# The found node is D and its probablity of being selected is 0.14284481366694815
# Closest nodes are: C, A, B
# The normalized distances are: 0.5713792546677926, 0.2857759316652593, 0.14284481366694815
# The found node is B and its probablity of being selected is 0.14284481366694815
# Closest nodes are: C, A, F
# The normalized distances are: 0.5713792546677926, 0.2857759316652593, 0.14284481366694815
# The found node is C and its probablity of being selected is 0.5713792546677926
# Closest nodes are: A, G, F
# The normalized distances are: 0.6896493885196742, 0.17241234712991854, 0.1379382643504073
# The found node is A and its probablity of being selected is 0.6896493885196742
# Closest nodes are: G, F
# The normalized distances are: 0.6665995420411309, 0.3334004579588691
# The found node is F and its probablity of being selected is 0.3334004579588691
# Closest nodes are: G
# The normalized distances are: 1.0
# The found node is G and its probablity of being selected is 1.0
# ['E', 'D', 'B', 'C', 'A', 'F', 'G']
# 8.414

# %% [markdown]
# **7. Defining the process of simulated annealing**
# The class below defines the simulated annealing process.  This class is an adaptation of the class anneal.py found in the python code provided in this github https://github.com/chncyhn/simulated-annealing-tsp. You are not asked to changed this class, just go through it and try to understand it so as to get a better understanding of the *simulated annealing* algorithm.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refining a greedy solution through simulated annealing.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Put comments in the code below explaining what it does.  Also run it a few times.  It will show you how there can be improvement (or not) from the greedy solution and randomized greedy solution to the annealed one.

# %%
# solve using greedy solution
firstSol = greedy_solution(moreCities)

# building a dictionary of all pairs or distances
distances = distDict(moreCities)

# printing the greedy solution path and the total distance of the path 
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))

# show the path taken by the first solution
showPath(firstSol, moreCities)


# Initialize the simulated annealing object with moreCities, randomized greedy will not be used
sa = SimAnneal(moreCities, False)

# perform a simulated annealing on the same data points 
betterSol = sa.anneal()

# show the path taken by the first better solution with the simulated annealing process.
showPath(betterSol, moreCities)


# solve using randomized greedy solution, k (the number of close nodes returned) is set as 4
secondSol = randomized_greedy_solution(moreCities, 4)

# printing the greedy solution path and the total distance of the path 
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))

# show the path taken by the second solution
showPath(secondSol, moreCities)


# Initialize the second simulated annealing object with moreCities, randomized greedy will be used 
# and k (the number of close nodes returned) is set as 4
sa2 = SimAnneal(moreCities, True, 4)

# perform a simulated annealing on the same data points 
betterSol2 = sa2.anneal()

# show the path taken by the second better solution with the simulated annealing process.
showPath(betterSol2, moreCities)
# Out:
# Solution ['E', 'G', 'A', 'C', 'B', 'D', 'F'] takes a total of 8.828
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over greedy heuristic:  0.1465
# Closest nodes are: C, A, D, F
# The normalized distances are: 0.4999622414476879, 0.2500566378284682, 0.12499056036192198, 0.12499056036192198
# The found node is C and its probablity of being selected is 0.4999622414476879
# Closest nodes are: A, D, G, E
# The normalized distances are: 0.40816123937042686, 0.40816123937042686, 0.10204030984260672, 0.08163721141653948
# The found node is A and its probablity of being selected is 0.40816123937042686
# Closest nodes are: G, D, E, F
# The normalized distances are: 0.3999275112433581, 0.2000241629188806, 0.2000241629188806, 0.2000241629188806
# The found node is D and its probablity of being selected is 0.2000241629188806
# Closest nodes are: E, G, F
# The normalized distances are: 0.4347448636601914, 0.34781703820407583, 0.21743809813573273
# The found node is F and its probablity of being selected is 0.21743809813573273
# Closest nodes are: G, E
# The normalized distances are: 0.8, 0.2
# The found node is G and its probablity of being selected is 0.8
# Closest nodes are: E
# The normalized distances are: 1.0
# The found node is E and its probablity of being selected is 1.0
# Solution ['B', 'C', 'A', 'D', 'F', 'G', 'E'] takes a total of 8.242
# Closest nodes are: A, B, D, G
# The normalized distances are: 0.3076923076923077, 0.3076923076923077, 0.3076923076923077, 0.07692307692307693
# The found node is D and its probablity of being selected is 0.3076923076923077
# Closest nodes are: A, B, E, G
# The normalized distances are: 0.4167358597292081, 0.20830500274978492, 0.20830500274978492, 0.16665413477122198
# The found node is G and its probablity of being selected is 0.16665413477122198
# Closest nodes are: A, E, F, B
# The normalized distances are: 0.31249881243230865, 0.31249881243230865, 0.31249881243230865, 0.06250356270307407
# The found node is E and its probablity of being selected is 0.31249881243230865
# Closest nodes are: A, F, B
# The normalized distances are: 0.5714778818058016, 0.28565264774274807, 0.1428694704514504
# The found node is A and its probablity of being selected is 0.5714778818058016
# Closest nodes are: B, F
# The normalized distances are: 0.5, 0.5
# The found node is F and its probablity of being selected is 0.5
# Closest nodes are: B
# The normalized distances are: 1.0
# The found node is B and its probablity of being selected is 1.0
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  6.828
# Improvement over randomized greedy heuristic:  0.2467

# %% [markdown]
# **9. Moving toward a larger example**
# There are a set of coordinates defined in the file *coord.txt* (available in the Jupyter Notebooks module in Brightspace). This data file is also from the github https://github.com/chncyhn/simulated-annealing-tsp.  It contains a larger example with 45 cities, to test.  Here is the beginning of the file:
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Make sure to put the file *coord.txt* in the same repertory as your notebook or modify the path below when opening the file to read.  We will assume the first number is the label, and the other two numbers are the coordinates.

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Show the nodes from that larger set of cities.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Testing the annealing process with the larger example. The steps are the same as the ones you had to comment in Question 4. Look at the additional step *plot_learning*, it shows the value of the fitness function as the annealing process occurs.  Run it multiple times, it is a probabilistic approach, so the result might be slightly different each time.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['7', '6', '8', '36', '4', '5', '35', '41', '40', '42', '31', '32', '33', '34', '30', '28', '37', '43', '39', '38', '2', '16', '10', '25', '1', '17', '3', '11', '18', '19', '12', '13', '15', '14', '21', '22', '9', '20', '26', '27', '23', '24', '45', '44', '29'] takes a total of 629.344
# 6.708203932499369
# 1e-08
# Best fitness obtained:  509.225
# Improvement over greedy heuristic:  0.046
# Closest nodes are: 6, 8, 28
# The normalized distances are: 0.9726620760251776, 0.021616027055004445, 0.005721896919818018
# The found node is 6 and its probablity of being selected is 0.9726620760251776
# Closest nodes are: 8, 28, 36
# The normalized distances are: 0.7709721059132427, 0.13582984307433077, 0.09319805101242656
# The found node is 8 and its probablity of being selected is 0.7709721059132427
# Closest nodes are: 36, 4, 5
# The normalized distances are: 0.5274524950525246, 0.23934501568265606, 0.23320248926481926
# The found node is 4 and its probablity of being selected is 0.23934501568265606
# Closest nodes are: 5, 36, 35
# The normalized distances are: 0.9860036978276586, 0.010687688937688984, 0.003308613234652485
# The found node is 5 and its probablity of being selected is 0.9860036978276586
# Closest nodes are: 36, 35, 41
# The normalized distances are: 0.6433851265956284, 0.2091419531027559, 0.14747292030161557
# The found node is 36 and its probablity of being selected is 0.6433851265956284
# Closest nodes are: 35, 32, 33
# The normalized distances are: 0.43915874633129964, 0.2934683141971396, 0.2673729394715607
# The found node is 35 and its probablity of being selected is 0.43915874633129964
# Closest nodes are: 41, 40, 32
# The normalized distances are: 0.4136553626466184, 0.35410025060929007, 0.23224438674409156
# The found node is 41 and its probablity of being selected is 0.4136553626466184
# Closest nodes are: 40, 42, 31
# The normalized distances are: 0.9930806986455647, 0.003863751020000157, 0.003055550334435161
# The found node is 40 and its probablity of being selected is 0.9930806986455647
# Closest nodes are: 42, 31, 43
# The normalized distances are: 0.4300173954022642, 0.3408746481649126, 0.22910795643282317
# The found node is 42 and its probablity of being selected is 0.4300173954022642
# Closest nodes are: 31, 32, 33
# The normalized distances are: 0.9839486552498172, 0.008482835201549554, 0.0075685095486331296
# The found node is 31 and its probablity of being selected is 0.9839486552498172
# Closest nodes are: 32, 33, 43
# The normalized distances are: 0.41243862227720784, 0.3762704376007119, 0.21129094012208027
# The found node is 32 and its probablity of being selected is 0.41243862227720784
# Closest nodes are: 33, 34, 43
# The normalized distances are: 0.9887666281525075, 0.007349401299634076, 0.003883970547858431
# The found node is 33 and its probablity of being selected is 0.9887666281525075
# Closest nodes are: 34, 43, 37
# The normalized distances are: 0.5693142368205822, 0.226712882634416, 0.2039728805450017
# The found node is 43 and its probablity of being selected is 0.226712882634416
# Closest nodes are: 37, 39, 38
# The normalized distances are: 0.4521427032053978, 0.3217511947862763, 0.2261061020083259
# The found node is 37 and its probablity of being selected is 0.4521427032053978
# Closest nodes are: 39, 38, 44
# The normalized distances are: 0.5209595056136637, 0.42479670334483544, 0.054243791041500865
# The found node is 39 and its probablity of being selected is 0.5209595056136637
# Closest nodes are: 38, 2, 10
# The normalized distances are: 0.9894640832648105, 0.005347052791698179, 0.0051888639434913945
# The found node is 38 and its probablity of being selected is 0.9894640832648105
# Closest nodes are: 2, 10, 16
# The normalized distances are: 0.3504561337857582, 0.331985512462817, 0.3175583537514248
# The found node is 2 and its probablity of being selected is 0.3504561337857582
# Closest nodes are: 16, 3, 10
# The normalized distances are: 0.448303482183377, 0.2758482589083115, 0.2758482589083115
# The found node is 16 and its probablity of being selected is 0.448303482183377
# Closest nodes are: 10, 25, 1
# The normalized distances are: 0.7614105084940352, 0.11959039522652605, 0.11899909627943875
# The found node is 10 and its probablity of being selected is 0.7614105084940352
# Closest nodes are: 25, 1, 3
# The normalized distances are: 0.47393105341577146, 0.4725242087641421, 0.05354473782008657
# The found node is 25 and its probablity of being selected is 0.47393105341577146
# Closest nodes are: 1, 17, 3
# The normalized distances are: 0.9999976725617995, 1.178907495112591e-06, 1.1485307054389632e-06
# The found node is 1 and its probablity of being selected is 0.9999976725617995
# Closest nodes are: 17, 3, 22
# The normalized distances are: 0.35537856851069033, 0.34623130415095826, 0.29839012733835135
# The found node is 17 and its probablity of being selected is 0.35537856851069033
# Closest nodes are: 3, 11, 18
# The normalized distances are: 0.7882774401941074, 0.12543216740230867, 0.08629039240358403
# The found node is 3 and its probablity of being selected is 0.7882774401941074
# Closest nodes are: 11, 18, 22
# The normalized distances are: 0.3921753292446367, 0.34865743676724903, 0.25916723398811436
# The found node is 18 and its probablity of being selected is 0.34865743676724903
# Closest nodes are: 11, 19, 12
# The normalized distances are: 0.5217769328126872, 0.41974724995099405, 0.058475817236318825
# The found node is 11 and its probablity of being selected is 0.5217769328126872
# Closest nodes are: 19, 21, 22
# The normalized distances are: 0.6987923355244147, 0.1518713926117719, 0.14933627186381357
# The found node is 21 and its probablity of being selected is 0.1518713926117719
# Closest nodes are: 22, 9, 20
# The normalized distances are: 0.9979067264855841, 0.0010707627242940222, 0.0010225107901218114
# The found node is 22 and its probablity of being selected is 0.9979067264855841
# Closest nodes are: 9, 20, 26
# The normalized distances are: 0.45580169865410375, 0.4038057829753993, 0.14039251837049702
# The found node is 9 and its probablity of being selected is 0.45580169865410375
# Closest nodes are: 20, 45, 44
# The normalized distances are: 0.4109467725736635, 0.29680860577326074, 0.29224462165307574
# The found node is 20 and its probablity of being selected is 0.4109467725736635
# Closest nodes are: 26, 27, 45
# The normalized distances are: 0.7631944657614956, 0.11969838022631916, 0.11710715401218523
# The found node is 26 and its probablity of being selected is 0.7631944657614956
# Closest nodes are: 27, 23, 24
# The normalized distances are: 0.36240245774960184, 0.3274377370724676, 0.3101598051779306
# The found node is 27 and its probablity of being selected is 0.36240245774960184
# Closest nodes are: 23, 24, 19
# The normalized distances are: 0.7140718936994623, 0.2855598596344917, 0.0003682466660460882
# The found node is 24 and its probablity of being selected is 0.2855598596344917
# Closest nodes are: 23, 19, 45
# The normalized distances are: 0.9995962624421874, 0.00024297786541207058, 0.00016075969240071845
# The found node is 23 and its probablity of being selected is 0.9995962624421874
# Closest nodes are: 19, 45, 44
# The normalized distances are: 0.4289282708654308, 0.28635596844927763, 0.28471576068529164
# The found node is 44 and its probablity of being selected is 0.28471576068529164
# Closest nodes are: 45, 34, 19
# The normalized distances are: 0.9990413226144181, 0.0006563942326968036, 0.00030228315288515883
# The found node is 45 and its probablity of being selected is 0.9990413226144181
# Closest nodes are: 34, 19, 30
# The normalized distances are: 0.5311199845314098, 0.2396275718123574, 0.2292524436562327
# The found node is 30 and its probablity of being selected is 0.2292524436562327
# Closest nodes are: 28, 34, 29
# The normalized distances are: 0.6688966480015157, 0.3136339117735217, 0.01746944022496272
# The found node is 28 and its probablity of being selected is 0.6688966480015157
# Closest nodes are: 34, 15, 14
# The normalized distances are: 0.8313257969300412, 0.08509137801160269, 0.08358282505835615
# The found node is 34 and its probablity of being selected is 0.8313257969300412
# Closest nodes are: 29, 19, 15
# The normalized distances are: 0.383679302470056, 0.33586323796637185, 0.28045745956357215
# The found node is 29 and its probablity of being selected is 0.383679302470056
# Closest nodes are: 19, 15, 13
# The normalized distances are: 0.38790359494977855, 0.30695037563704125, 0.3051460294131802
# The found node is 15 and its probablity of being selected is 0.30695037563704125
# Closest nodes are: 13, 14, 12
# The normalized distances are: 0.5539459359827119, 0.4431836943547862, 0.0028703696625019095
# The found node is 13 and its probablity of being selected is 0.5539459359827119
# Closest nodes are: 14, 12, 19
# The normalized distances are: 0.9916837903528758, 0.007291802013147522, 0.0010244076339767326
# The found node is 14 and its probablity of being selected is 0.9916837903528758
# Closest nodes are: 12, 19
# The normalized distances are: 0.8677981130790676, 0.13220188692093243
# The found node is 12 and its probablity of being selected is 0.8677981130790676
# Closest nodes are: 19
# The normalized distances are: 1.0
# The found node is 19 and its probablity of being selected is 1.0
# Solution ['7', '6', '8', '4', '5', '36', '35', '41', '40', '42', '31', '32', '33', '43', '37', '39', '38', '2', '16', '10', '25', '1', '17', '3', '18', '11', '21', '22', '9', '20', '26', '27', '24', '23', '44', '45', '30', '28', '34', '29', '15', '13', '14', '12', '19'] takes a total of 768.513
# Closest nodes are: 4, 5, 8, 35
# The normalized distances are: 0.3166333622865689, 0.2698675858535445, 0.2429153326083497, 0.1705837192515369
# The found node is 4 and its probablity of being selected is 0.3166333622865689
# Closest nodes are: 5, 8, 35, 41
# The normalized distances are: 0.990651085958325, 0.0037382235886579004, 0.003324207912349503, 0.002286482540667476
# The found node is 5 and its probablity of being selected is 0.990651085958325
# Closest nodes are: 8, 35, 6, 41
# The normalized distances are: 0.33243629800821295, 0.2715342049519522, 0.20456173281575624, 0.19146776422407868
# The found node is 41 and its probablity of being selected is 0.19146776422407868
# Closest nodes are: 40, 35, 42, 31
# The normalized distances are: 0.9859330476463793, 0.007197452340916298, 0.003835941856176539, 0.003033558156527793
# The found node is 40 and its probablity of being selected is 0.9859330476463793
# Closest nodes are: 35, 42, 31, 43
# The normalized distances are: 0.41129212691430334, 0.25315462623711804, 0.20067558911000088, 0.1348776577385778
# The found node is 35 and its probablity of being selected is 0.41129212691430334
# Closest nodes are: 32, 33, 42, 31
# The normalized distances are: 0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381
# The found node is 33 and its probablity of being selected is 0.2735206022481365
# Closest nodes are: 32, 42, 31, 34
# The normalized distances are: 0.9625946372334128, 0.014804037734449792, 0.014047512288555542, 0.008553812743581938
# The found node is 32 and its probablity of being selected is 0.9625946372334128
# Closest nodes are: 42, 31, 34, 43
# The normalized distances are: 0.38653378197635785, 0.3587032037100294, 0.1666779711305563, 0.0880850431830564
# The found node is 31 and its probablity of being selected is 0.3587032037100294
# Closest nodes are: 42, 43, 44, 45
# The normalized distances are: 0.9893133723213091, 0.004054822244050477, 0.003388062464607192, 0.003243742970033182
# The found node is 42 and its probablity of being selected is 0.9893133723213091
# Closest nodes are: 43, 44, 45, 37
# The normalized distances are: 0.3235084476390142, 0.23866058367376558, 0.227455276316292, 0.21037569237092818
# The found node is 43 and its probablity of being selected is 0.3235084476390142
# Closest nodes are: 37, 39, 38, 44
# The normalized distances are: 0.4259418848926554, 0.30310631887267914, 0.21300367913138005, 0.057948117103285485
# The found node is 39 and its probablity of being selected is 0.30310631887267914
# Closest nodes are: 38, 37, 2, 10
# The normalized distances are: 0.9538583463356912, 0.03598487052873662, 0.0051546397892786, 0.005002143346293626
# The found node is 38 and its probablity of being selected is 0.9538583463356912
# Closest nodes are: 37, 2, 10, 16
# The normalized distances are: 0.6388083800493115, 0.1265818186837332, 0.11991038504660434, 0.11469941622035093
# The found node is 16 and its probablity of being selected is 0.11469941622035093
# Closest nodes are: 10, 25, 1, 2
# The normalized distances are: 0.6952331797594411, 0.1091963005691526, 0.10865639385314865, 0.08691412581825766
# The found node is 25 and its probablity of being selected is 0.1091963005691526
# Closest nodes are: 1, 10, 2, 17
# The normalized distances are: 0.9999820413046817, 1.3829631115689315e-05, 2.950175135290622e-06, 1.1788890672635273e-06
# The found node is 1 and its probablity of being selected is 0.9999820413046817
# Closest nodes are: 10, 2, 17, 3
# The normalized distances are: 0.7237323226574719, 0.15437060033392766, 0.06174315730281158, 0.060153919705788754
# The found node is 2 and its probablity of being selected is 0.15437060033392766
# Closest nodes are: 3, 10, 17, 22
# The normalized distances are: 0.406380055589063, 0.406380055589063, 0.16106121763028697, 0.02617867119158702
# The found node is 3 and its probablity of being selected is 0.406380055589063
# Closest nodes are: 17, 10, 11, 18
# The normalized distances are: 0.6795338994097823, 0.21500877286012643, 0.055826043502974126, 0.04963128422711736
# The found node is 17 and its probablity of being selected is 0.6795338994097823
# Closest nodes are: 10, 11, 18, 22
# The normalized distances are: 0.4214728837756993, 0.27903917549409357, 0.19196351660040523, 0.10752442412980191
# The found node is 11 and its probablity of being selected is 0.27903917549409357
# Closest nodes are: 18, 19, 10, 21
# The normalized distances are: 0.46048829548284, 0.3555033059803113, 0.10674541293641131, 0.07726298560043723
# The found node is 10 and its probablity of being selected is 0.10674541293641131
# Closest nodes are: 22, 21, 18, 9
# The normalized distances are: 0.3963037256782955, 0.3779427496011899, 0.11416961633363505, 0.11158390838687945
# The found node is 22 and its probablity of being selected is 0.3963037256782955
# Closest nodes are: 21, 9, 20, 26
# The normalized distances are: 0.9975708062316889, 0.0011072306459561398, 0.0009809224916118042, 0.0003410406307431059
# The found node is 21 and its probablity of being selected is 0.9975708062316889
# Closest nodes are: 9, 20, 26, 18
# The normalized distances are: 0.3915455687533708, 0.37390129464832583, 0.1292121131986696, 0.10534102339963378
# The found node is 20 and its probablity of being selected is 0.37390129464832583
# Closest nodes are: 26, 9, 27, 45
# The normalized distances are: 0.49254846382271306, 0.35462259500105137, 0.07725063001303933, 0.07557831116319633
# The found node is 27 and its probablity of being selected is 0.07725063001303933
# Closest nodes are: 23, 24, 26, 9
# The normalized distances are: 0.7126108695025517, 0.28497559092391284, 0.001951698456598506, 0.00046184111693679385
# The found node is 23 and its probablity of being selected is 0.7126108695025517
# Closest nodes are: 24, 26, 9, 19
# The normalized distances are: 0.9982081294813807, 0.001235435725307622, 0.00030990469142983456, 0.0002465301018818126
# The found node is 24 and its probablity of being selected is 0.9982081294813807
# Closest nodes are: 26, 9, 19, 18
# The normalized distances are: 0.6118249465855671, 0.15662949730271455, 0.12685670639007426, 0.10468884972164423
# The found node is 26 and its probablity of being selected is 0.6118249465855671
# Closest nodes are: 9, 19, 18, 44
# The normalized distances are: 0.3662438095151115, 0.27549407774590173, 0.21947246822938737, 0.1387896445095995
# The found node is 9 and its probablity of being selected is 0.3662438095151115
# Closest nodes are: 45, 44, 37, 18
# The normalized distances are: 0.39211963671359223, 0.38609006829689785, 0.13050751363856014, 0.0912827813509498
# The found node is 45 and its probablity of being selected is 0.39211963671359223
# Closest nodes are: 44, 37, 34, 8
# The normalized distances are: 0.9971661246240185, 0.0017999701446506891, 0.0006538877438638437, 0.00038001748746687835
# The found node is 44 and its probablity of being selected is 0.9971661246240185
# Closest nodes are: 37, 34, 8, 18
# The normalized distances are: 0.5783866625611526, 0.19342662997711244, 0.11495581331485853, 0.11323089414687645
# The found node is 37 and its probablity of being selected is 0.5783866625611526
# Closest nodes are: 8, 34, 6, 18
# The normalized distances are: 0.3028765009724524, 0.2476985193631925, 0.22681724039081838, 0.22260773927353675
# The found node is 34 and its probablity of being selected is 0.2476985193631925
# Closest nodes are: 30, 8, 28, 6
# The normalized distances are: 0.4089441616032654, 0.2187543820766742, 0.19709935174200063, 0.17520210457805988
# The found node is 28 and its probablity of being selected is 0.19709935174200063
# Closest nodes are: 7, 6, 30, 8
# The normalized distances are: 0.31344186279225394, 0.27608919077013927, 0.2357695085153536, 0.17469943792225318
# The found node is 8 and its probablity of being selected is 0.17469943792225318
# Closest nodes are: 6, 7, 30, 18
# The normalized distances are: 0.5520585880102844, 0.41714317779893334, 0.027400863095238467, 0.003397371095543987
# The found node is 6 and its probablity of being selected is 0.5520585880102844
# Closest nodes are: 7, 30, 18, 15
# The normalized distances are: 0.998173733883757, 0.0015285806465850005, 0.0001595299355563653, 0.0001381555341015581
# The found node is 7 and its probablity of being selected is 0.998173733883757
# Closest nodes are: 30, 18, 15, 14
# The normalized distances are: 0.7896637200926911, 0.07729284384026869, 0.06719658659051199, 0.06584684947652822
# The found node is 30 and its probablity of being selected is 0.7896637200926911
# Closest nodes are: 29, 18, 19, 15
# The normalized distances are: 0.28685198682823587, 0.27157273536426135, 0.22505747942450982, 0.21651779838299295
# The found node is 29 and its probablity of being selected is 0.28685198682823587
# Closest nodes are: 18, 19, 15, 13
# The normalized distances are: 0.29443511980717213, 0.2736911534971077, 0.21657340501149255, 0.21530032168422764
# The found node is 18 and its probablity of being selected is 0.29443511980717213
# Closest nodes are: 19, 12, 13, 15
# The normalized distances are: 0.7484453956124768, 0.10426740418265816, 0.07374933386000691, 0.07353786634485798
# The found node is 19 and its probablity of being selected is 0.7484453956124768
# Closest nodes are: 12, 13, 15, 14
# The normalized distances are: 0.37998432036733976, 0.2122894231081768, 0.20832997543509302, 0.1993962810893905
# The found node is 14 and its probablity of being selected is 0.1993962810893905
# Closest nodes are: 13, 15, 12
# The normalized distances are: 0.49841281139111787, 0.49841281139111787, 0.0031743772177642883
# The found node is 13 and its probablity of being selected is 0.49841281139111787
# Closest nodes are: 15, 12
# The normalized distances are: 0.9941516857613738, 0.005848314238626333
# The found node is 15 and its probablity of being selected is 0.9941516857613738
# Closest nodes are: 12
# The normalized distances are: 1.0
# The found node is 12 and its probablity of being selected is 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  525.492
# Improvement over randomized greedy heuristic:  0.3049

# %% [markdown]
# **(TO DO) Q6 - 2 marks**
# Try the annealing again, but provide a different temperature schedule, by changing alpha, and the starting and stopping temperatures.  These are all parameters to the class which can be set.  Try also changing the number of iterations to do.  Explore 4 variations below.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters k, T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, False, stopping_iter=100) means that I set a maximum of 100 iterations for a 
# Greedy solution. Calling  SimAnneal(manyCities, True, k=3, stopping_iter=100) is the same for a randomized greedy solution
# with k = 3.
# Try four variations and look at the differences
# The key point of this question is to use different parameters to understand how they work
# What you need to do is create and run these four different examples

# Test 1 (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, alpha=3)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, T=-10)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False, stopping_T=-10)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, stopping_iter=-1)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# 1e-08
# Best fitness obtained:  585.012
# Improvement over greedy heuristic:  0.0
# Closest nodes are: 3, 2, 16, 10
# The normalized distances are: 0.4888004709492067, 0.24142911342538773, 0.15228988389967577, 0.11748053172572977
# The found node is 10 and its probablity of being selected is 0.11748053172572977
# Closest nodes are: 16, 25, 1, 2
# The normalized distances are: 0.7031675566501439, 0.12155164126487171, 0.12119082026532384, 0.05408998181966063
# The found node is 2 and its probablity of being selected is 0.05408998181966063
# Closest nodes are: 16, 3, 25, 1
# The normalized distances are: 0.45364886911962155, 0.27913736046151144, 0.13381326318070585, 0.1334005072381612
# The found node is 3 and its probablity of being selected is 0.27913736046151144
# Closest nodes are: 16, 25, 1, 11
# The normalized distances are: 0.4291913778935285, 0.2427847129198727, 0.24226516521313726, 0.08575874397346141
# The found node is 16 and its probablity of being selected is 0.4291913778935285
# Closest nodes are: 25, 1, 22, 21
# The normalized distances are: 0.4783275526911553, 0.47596252515082993, 0.023317059482695433, 0.022392862675319265
# The found node is 25 and its probablity of being selected is 0.4783275526911553
# Closest nodes are: 1, 22, 21, 11
# The normalized distances are: 0.9999977399899933, 9.859475826980375e-07, 9.418620934367672e-07, 3.3220033053675165e-07
# The found node is 1 and its probablity of being selected is 0.9999977399899933
# Closest nodes are: 22, 21, 11, 38
# The normalized distances are: 0.3974381874088188, 0.37957810357381505, 0.13356383873167352, 0.08941987028569254
# The found node is 22 and its probablity of being selected is 0.3974381874088188
# Closest nodes are: 21, 9, 20, 11
# The normalized distances are: 0.9974058791330165, 0.0011070475889371715, 0.0009807603169575808, 0.0005063129610887983
# The found node is 21 and its probablity of being selected is 0.9974058791330165
# Closest nodes are: 9, 20, 11, 26
# The normalized distances are: 0.3615246179764595, 0.34523318228071737, 0.17393715943599708, 0.11930504030682615
# The found node is 20 and its probablity of being selected is 0.34523318228071737
# Closest nodes are: 26, 9, 11, 27
# The normalized distances are: 0.47675323707183487, 0.34325042614774925, 0.10522300861141064, 0.07477332816900527
# The found node is 9 and its probablity of being selected is 0.34325042614774925
# Closest nodes are: 45, 44, 39, 38
# The normalized distances are: 0.3402455570407368, 0.33501364903978176, 0.16340674819338669, 0.16133404572609492
# The found node is 39 and its probablity of being selected is 0.16340674819338669
# Closest nodes are: 38, 43, 37, 40
# The normalized distances are: 0.9237498585971928, 0.035519121251156215, 0.034849010013128554, 0.0058820101385223394
# The found node is 38 and its probablity of being selected is 0.9237498585971928
# Closest nodes are: 37, 43, 40, 41
# The normalized distances are: 0.44827909391767184, 0.3937632642697459, 0.0809312560337024, 0.07702638577888
# The found node is 40 and its probablity of being selected is 0.0809312560337024
# Closest nodes are: 41, 35, 42, 31
# The normalized distances are: 0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556
# The found node is 41 and its probablity of being selected is 0.9870259769962175
# Closest nodes are: 35, 42, 31, 32
# The normalized distances are: 0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421
# The found node is 35 and its probablity of being selected is 0.44929794491405184
# Closest nodes are: 32, 33, 42, 31
# The normalized distances are: 0.38119730219063996, 0.2735206022481365, 0.18602370035418545, 0.1592583952070381
# The found node is 33 and its probablity of being selected is 0.2735206022481365
# Closest nodes are: 32, 42, 31, 34
# The normalized distances are: 0.9625946372334128, 0.014804037734449792, 0.014047512288555542, 0.008553812743581938
# The found node is 32 and its probablity of being selected is 0.9625946372334128
# Closest nodes are: 42, 31, 36, 34
# The normalized distances are: 0.35563698318443526, 0.3300309860984658, 0.16097712726444546, 0.15335490345265365
# The found node is 31 and its probablity of being selected is 0.3300309860984658
# Closest nodes are: 42, 43, 44, 45
# The normalized distances are: 0.9893133723213091, 0.004054822244050477, 0.003388062464607192, 0.003243742970033182
# The found node is 42 and its probablity of being selected is 0.9893133723213091
# Closest nodes are: 43, 44, 45, 37
# The normalized distances are: 0.3235084476390142, 0.23866058367376558, 0.227455276316292, 0.21037569237092818
# The found node is 44 and its probablity of being selected is 0.23866058367376558
# Closest nodes are: 45, 43, 37, 34
# The normalized distances are: 0.9937410960596154, 0.0036536471076680423, 0.0019523449766381934, 0.0006529118560785327
# The found node is 45 and its probablity of being selected is 0.9937410960596154
# Closest nodes are: 43, 37, 34, 36
# The normalized distances are: 0.5168817811375913, 0.2845617056348904, 0.10337472109780778, 0.09518179212971054
# The found node is 37 and its probablity of being selected is 0.2845617056348904
# Closest nodes are: 43, 4, 5, 36
# The normalized distances are: 0.8330313084781247, 0.06103985660288962, 0.05815818678176797, 0.047770648137217854
# The found node is 43 and its probablity of being selected is 0.8330313084781247
# Closest nodes are: 4, 5, 36, 34
# The normalized distances are: 0.29660431187340125, 0.2821828100713704, 0.27311905377707657, 0.14809382427815193
# The found node is 36 and its probablity of being selected is 0.27311905377707657
# Closest nodes are: 4, 5, 8, 6
# The normalized distances are: 0.3392720587043724, 0.28916261624776607, 0.26028332703078544, 0.11128199801707608
# The found node is 4 and its probablity of being selected is 0.3392720587043724
# Closest nodes are: 5, 8, 6, 7
# The normalized distances are: 0.9919580068449682, 0.003743155256887218, 0.0022493378840021954, 0.0020495000141424963
# The found node is 5 and its probablity of being selected is 0.9919580068449682
# Closest nodes are: 8, 6, 7, 28
# The normalized distances are: 0.41459114049192, 0.25511498779532354, 0.23249505060036987, 0.09779882111238664
# The found node is 6 and its probablity of being selected is 0.25511498779532354
# Closest nodes are: 7, 8, 28, 30
# The normalized distances are: 0.9651351349517865, 0.028385859131906277, 0.005001019831774255, 0.0014779860845329648
# The found node is 7 and its probablity of being selected is 0.9651351349517865
# Closest nodes are: 8, 28, 30, 34
# The normalized distances are: 0.7267976598644371, 0.19238786483413806, 0.052075985194196796, 0.028738490107228197
# The found node is 28 and its probablity of being selected is 0.19238786483413806
# Closest nodes are: 30, 8, 34, 18
# The normalized distances are: 0.5015394810046332, 0.3716284857149887, 0.1133418520817038, 0.013490181198674261
# The found node is 8 and its probablity of being selected is 0.3716284857149887
# Closest nodes are: 30, 34, 18, 11
# The normalized distances are: 0.5000602679812801, 0.38018483469451075, 0.06200134260605837, 0.057753554718150885
# The found node is 34 and its probablity of being selected is 0.38018483469451075
# Closest nodes are: 30, 11, 18, 29
# The normalized distances are: 0.8248203158916693, 0.06034162189127608, 0.05935329236064898, 0.055484769856405644
# The found node is 30 and its probablity of being selected is 0.8248203158916693
# Closest nodes are: 29, 18, 11, 19
# The normalized distances are: 0.27332535450704454, 0.2587666029042753, 0.25346324815537563, 0.21444479443330455
# The found node is 11 and its probablity of being selected is 0.25346324815537563
# Closest nodes are: 18, 19, 26, 12
# The normalized distances are: 0.5231566392940825, 0.40388413047411814, 0.03666769718739628, 0.03629153304440287
# The found node is 19 and its probablity of being selected is 0.40388413047411814
# Closest nodes are: 18, 12, 13, 15
# The normalized distances are: 0.7605708470330056, 0.1136383978956378, 0.0634874352417514, 0.062303319829605235
# The found node is 18 and its probablity of being selected is 0.7605708470330056
# Closest nodes are: 12, 13, 15, 14
# The normalized distances are: 0.3249941585131191, 0.22987148175999594, 0.22921235240238488, 0.21592200732450023
# The found node is 14 and its probablity of being selected is 0.21592200732450023
# Closest nodes are: 13, 15, 12, 26
# The normalized distances are: 0.49835639668271975, 0.49835639668271975, 0.003174017914068651, 0.00011318872049187295
# The found node is 13 and its probablity of being selected is 0.49835639668271975
# Closest nodes are: 15, 12, 26, 27
# The normalized distances are: 0.993860824770247, 0.005846603185373363, 0.0001860821538764563, 0.00010648989050323053
# The found node is 15 and its probablity of being selected is 0.993860824770247
# Closest nodes are: 12, 26, 27, 23
# The normalized distances are: 0.9291325715686931, 0.03330421243594184, 0.019039342879184983, 0.018523873116180097
# The found node is 12 and its probablity of being selected is 0.9291325715686931
# Closest nodes are: 26, 27, 23, 24
# The normalized distances are: 0.3815123157196001, 0.21089489580535012, 0.20466501994323624, 0.20292776853181357
# The found node is 26 and its probablity of being selected is 0.3815123157196001
# Closest nodes are: 27, 23, 24, 29
# The normalized distances are: 0.357565358303892, 0.32306732273716515, 0.3060200048271719, 0.013347314131770992
# The found node is 27 and its probablity of being selected is 0.357565358303892
# Closest nodes are: 23, 24, 29
# The normalized distances are: 0.7142892403416772, 0.2856467773204986, 6.398233782435296e-05
# The found node is 23 and its probablity of being selected is 0.7142892403416772
# Closest nodes are: 24, 29
# The normalized distances are: 0.9999554881224133, 4.451187758678297e-05
# The found node is 24 and its probablity of being selected is 0.9999554881224133
# Closest nodes are: 29
# The normalized distances are: 1.0
# The found node is 29 and its probablity of being selected is 1.0
# -10
# 1e-08
# Best fitness obtained:  752.654
# Improvement over randomized greedy heuristic:  0.0
# 6.708203932499369
# -10
# Best fitness obtained:  540.249
# Improvement over greedy heuristic:  0.1333
# Closest nodes are: 7, 8, 28, 36
# The normalized distances are: 0.9632535108065308, 0.028330518158407172, 0.004991269860681514, 0.0034247011743805253
# The found node is 7 and its probablity of being selected is 0.9632535108065308
# Closest nodes are: 8, 28, 36, 4
# The normalized distances are: 0.6658783835833598, 0.176262153184016, 0.0959530470797446, 0.061906416152879576
# The found node is 8 and its probablity of being selected is 0.6658783835833598
# Closest nodes are: 36, 4, 5, 28
# The normalized distances are: 0.436645141164977, 0.1981388639549043, 0.19305384807198792, 0.17216214680813058
# The found node is 28 and its probablity of being selected is 0.17216214680813058
# Closest nodes are: 30, 36, 34, 4
# The normalized distances are: 0.5765470541216106, 0.17866426996047827, 0.1302926557157521, 0.11449602020215911
# The found node is 30 and its probablity of being selected is 0.5765470541216106
# Closest nodes are: 34, 33, 36, 32
# The normalized distances are: 0.40742453431598913, 0.20349781125878047, 0.1975019835936928, 0.19157567083153768
# The found node is 34 and its probablity of being selected is 0.40742453431598913
# Closest nodes are: 33, 32, 31, 42
# The normalized distances are: 0.37867042596557676, 0.3167402455586712, 0.1537948141518229, 0.1507945143239292
# The found node is 31 and its probablity of being selected is 0.1537948141518229
# Closest nodes are: 42, 41, 40, 32
# The normalized distances are: 0.9685192451611889, 0.011919914695735598, 0.011812215065381344, 0.007748625077694236
# The found node is 42 and its probablity of being selected is 0.9685192451611889
# Closest nodes are: 41, 40, 32, 35
# The normalized distances are: 0.32715346462068273, 0.3234307838814053, 0.18123227175071518, 0.16818347974719688
# The found node is 41 and its probablity of being selected is 0.32715346462068273
# Closest nodes are: 40, 35, 32, 43
# The normalized distances are: 0.9889664193861917, 0.007219596388711126, 0.0019583850848774926, 0.0018555991402197383
# The found node is 40 and its probablity of being selected is 0.9889664193861917
# Closest nodes are: 35, 43, 32, 37
# The normalized distances are: 0.5295466192714873, 0.17365760975434988, 0.15462596513275795, 0.14216980584140484
# The found node is 35 and its probablity of being selected is 0.5295466192714873
# Closest nodes are: 32, 33, 36, 37
# The normalized distances are: 0.43652967722969455, 0.31322325611669155, 0.1554898376651568, 0.09475722898845707
# The found node is 32 and its probablity of being selected is 0.43652967722969455
# Closest nodes are: 33, 36, 43, 4
# The normalized distances are: 0.9847544478785487, 0.007683385412766577, 0.0038682103173115407, 0.0036939563913731136
# The found node is 33 and its probablity of being selected is 0.9847544478785487
# Closest nodes are: 36, 43, 4, 37
# The normalized distances are: 0.4121217205135568, 0.20515639481442785, 0.19814330966441213, 0.1845785750076032
# The found node is 36 and its probablity of being selected is 0.4121217205135568
# Closest nodes are: 4, 5, 37, 43
# The normalized distances are: 0.47334685942144844, 0.40343498013267304, 0.06767658175498172, 0.05554157869089685
# The found node is 4 and its probablity of being selected is 0.47334685942144844
# Closest nodes are: 5, 37, 43, 39
# The normalized distances are: 0.9955119963782039, 0.0019713468600215164, 0.0013750419261919344, 0.0011416148355827295
# The found node is 5 and its probablity of being selected is 0.9955119963782039
# Closest nodes are: 37, 43, 39, 38
# The normalized distances are: 0.3499323399649554, 0.24372086806120835, 0.20584276625180245, 0.20050402572203385
# The found node is 43 and its probablity of being selected is 0.24372086806120835
# Closest nodes are: 37, 39, 38, 44
# The normalized distances are: 0.4259418848926554, 0.30310631887267914, 0.21300367913138005, 0.057948117103285485
# The found node is 37 and its probablity of being selected is 0.4259418848926554
# Closest nodes are: 39, 38, 44, 45
# The normalized distances are: 0.49622825926067754, 0.40463054492532013, 0.051668703064582155, 0.047472492749420156
# The found node is 38 and its probablity of being selected is 0.40463054492532013
# Closest nodes are: 39, 2, 10, 16
# The normalized distances are: 0.9829041205039546, 0.005991355831851364, 0.0056755843154972715, 0.005428939348696986
# The found node is 39 and its probablity of being selected is 0.9829041205039546
# Closest nodes are: 2, 10, 16, 44
# The normalized distances are: 0.26238722888083693, 0.25462468470224325, 0.24269849478650735, 0.24028959163041244
# The found node is 16 and its probablity of being selected is 0.24269849478650735
# Closest nodes are: 10, 25, 1, 2
# The normalized distances are: 0.6952331797594411, 0.1091963005691526, 0.10865639385314865, 0.08691412581825766
# The found node is 10 and its probablity of being selected is 0.6952331797594411
# Closest nodes are: 25, 1, 2, 3
# The normalized distances are: 0.3913882903885666, 0.39022647050131715, 0.17416618394657402, 0.04421905516354229
# The found node is 1 and its probablity of being selected is 0.39022647050131715
# Closest nodes are: 25, 2, 17, 3
# The normalized distances are: 0.9999947364698543, 2.9411124612616073e-06, 1.1763481449713842e-06, 1.1460695395219113e-06
# The found node is 25 and its probablity of being selected is 0.9999947364698543
# Closest nodes are: 2, 17, 3, 22
# The normalized distances are: 0.47100995739604196, 0.1882154326040559, 0.1833657046709934, 0.1574089053289089
# The found node is 17 and its probablity of being selected is 0.1882154326040559
# Closest nodes are: 3, 2, 11, 18
# The normalized distances are: 0.5673725090234292, 0.28023754062564826, 0.09028136529414107, 0.062108585056781525
# The found node is 3 and its probablity of being selected is 0.5673725090234292
# Closest nodes are: 2, 11, 18, 22
# The normalized distances are: 0.8560972414300402, 0.056435111721385475, 0.05017276694673849, 0.037294879901835915
# The found node is 2 and its probablity of being selected is 0.8560972414300402
# Closest nodes are: 22, 21, 11, 18
# The normalized distances are: 0.28934921051724455, 0.28069407048868206, 0.24470791121195712, 0.18524880778211616
# The found node is 11 and its probablity of being selected is 0.24470791121195712
# Closest nodes are: 18, 19, 21, 22
# The normalized distances are: 0.47510839935055066, 0.3667902275149769, 0.07971601836085387, 0.0783853547736184
# The found node is 18 and its probablity of being selected is 0.47510839935055066
# Closest nodes are: 19, 12, 21, 22
# The normalized distances are: 0.7289320982842825, 0.1015489682468071, 0.08501541975309784, 0.0845035137158125
# The found node is 19 and its probablity of being selected is 0.7289320982842825
# Closest nodes are: 12, 21, 22, 13
# The normalized distances are: 0.346184770264016, 0.23193000353237966, 0.22847891644550994, 0.1934063097580944
# The found node is 22 and its probablity of being selected is 0.22847891644550994
# Closest nodes are: 21, 9, 20, 26
# The normalized distances are: 0.9975708062316889, 0.0011072306459561398, 0.0009809224916118042, 0.0003410406307431059
# The found node is 21 and its probablity of being selected is 0.9975708062316889
# Closest nodes are: 9, 20, 26, 44
# The normalized distances are: 0.3940653728133924, 0.37630754841669783, 0.13004366189548824, 0.09958341687442154
# The found node is 9 and its probablity of being selected is 0.3940653728133924
# Closest nodes are: 20, 45, 44, 26
# The normalized distances are: 0.3666330718733776, 0.2648027875035777, 0.2607309523423348, 0.1078331882807099
# The found node is 20 and its probablity of being selected is 0.3666330718733776
# Closest nodes are: 26, 27, 45, 44
# The normalized distances are: 0.6834224909105233, 0.10718705237282283, 0.10486667093241353, 0.10452378578424036
# The found node is 26 and its probablity of being selected is 0.6834224909105233
# Closest nodes are: 27, 23, 24, 44
# The normalized distances are: 0.3322573554919532, 0.3002010452234222, 0.28436031391244576, 0.08318128537217899
# The found node is 24 and its probablity of being selected is 0.28436031391244576
# Closest nodes are: 23, 27, 45, 44
# The normalized distances are: 0.8331022111692606, 0.16663057337271317, 0.0001339833493161692, 0.0001332321087100162
# The found node is 23 and its probablity of being selected is 0.8331022111692606
# Closest nodes are: 27, 45, 44, 12
# The normalized distances are: 0.9990798131428544, 0.0003293589149852859, 0.0003274723922338226, 0.0002633555499265387
# The found node is 27 and its probablity of being selected is 0.9990798131428544
# Closest nodes are: 45, 44, 12, 13
# The normalized distances are: 0.29209793573239046, 0.2904669650604026, 0.23337225894057706, 0.18406284026662997
# The found node is 44 and its probablity of being selected is 0.2904669650604026
# Closest nodes are: 45, 12, 15, 13
# The normalized distances are: 0.9994951330527323, 0.0001692625023167708, 0.00016871755783622364, 0.00016688688711462282
# The found node is 45 and its probablity of being selected is 0.9994951330527323
# Closest nodes are: 12, 15, 13, 14
# The normalized distances are: 0.25347125207314536, 0.25209312820444774, 0.24942134911154012, 0.24501427061086672
# The found node is 14 and its probablity of being selected is 0.24501427061086672
# Closest nodes are: 13, 15, 12, 29
# The normalized distances are: 0.4984030042945117, 0.4984030042945117, 0.0031743147566410434, 1.967665433564341e-05
# The found node is 15 and its probablity of being selected is 0.4984030042945117
# Closest nodes are: 13, 12, 29
# The normalized distances are: 0.9948133782603923, 0.005154802942536225, 3.1818797071350226e-05
# The found node is 13 and its probablity of being selected is 0.9948133782603923
# Closest nodes are: 12, 29
# The normalized distances are: 0.9946239591029167, 0.0053760408970832604
# The found node is 12 and its probablity of being selected is 0.9946239591029167
# Closest nodes are: 29
# The normalized distances are: 1.0
# The found node is 29 and its probablity of being selected is 1.0
# 6.708203932499369
# 1e-08
# Best fitness obtained:  503.794
# Improvement over randomized greedy heuristic:  0.3018

# %% [markdown]
# ***SIGNATURE:***
# My name is Ellen Li.
# My student number is 300015724.
# I certify being the author of this assignment.
